# %% [markdown]
# # Project: Train a Quadcopter How to Fly
#
# Design an agent to fly a quadcopter, and then train it using a reinforcement learning algorithm of your choice!
#
# Try to apply the techniques you have learnt, but also feel free to come up with innovative ideas and test them.

# %% [markdown]
# ## Instructions
#
# Take a look at the files in the directory to better understand the structure of the project.
#
# - `task.py`: Define your task (environment) in this file.
# - `agents/`: Folder containing reinforcement learning agents.
#     - `policy_search.py`: A sample agent has been provided here.
#     - `agent.py`: Develop your agent here.
# - `physics_sim.py`: This file contains the simulator for the quadcopter.  **DO NOT MODIFY THIS FILE**.
#
# For this project, you will define your own task in `task.py`.  Although we have provided a example task to get you started, you are encouraged to change it.  Later in this notebook, you will learn more about how to amend this file.
#
# You will also design a reinforcement learning agent in `agent.py` to complete your chosen task.
#
# You are welcome to create any additional files to help you to organize your code.  For instance, you may find it useful to define a `model.py` file defining any needed neural network architectures.
#
# ## Controlling the Quadcopter
#
# We provide a sample agent in the code cell below to show you how to use the sim to control the quadcopter.  This agent is even simpler than the sample agent that you'll examine (in `agents/policy_search.py`) later in this notebook!
#
# The agent controls the quadcopter by setting the revolutions per second on each of its four rotors.  The provided agent in the `Basic_Agent` class below always selects a random action for each of the four rotors.  These four speeds are returned by the `act` method as a list of four floating-point numbers.
#
# For this project, the agent that you will implement in `agents/agent.py` will have a far more intelligent method for selecting actions!

# %%
import random

class Basic_Agent():
    def __init__(self, task):
        self.task = task
    
    def act(self):
        new_thrust = random.gauss(450., 25.)
        return [new_thrust + random.gauss(0., 1.) for x in range(4)]

# %% [markdown]
# Run the code cell below to have the agent select actions to control the quadcopter.
#
# Feel free to change the provided values of `runtime`, `init_pose`, `init_velocities`, and `init_angle_velocities` below to change the starting conditions of the quadcopter.
#
# The `labels` list below annotates statistics that are saved while running the simulation.  All of this information is saved in a text file `data.txt` and stored in the dictionary `results`.

# %%
#%load_ext autoreload
# %reload_ext autoreload

#%autoreload 2

import csv
import numpy as np
from task import Task

# Modify the values below to give the quadcopter a different starting position.
runtime = 5.                                     # time limit of the episode
init_pose = np.array([0., 0., 10., 0., 0., 0.])  # initial pose
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
file_output = 'data.txt'                         # file name for saved results

# Setup
task = Task(init_pose, init_velocities, init_angle_velocities, runtime)
agent = Basic_Agent(task)
done = False
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

# Run the simulation, and save the results.
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    while True:
        rotor_speeds = agent.act()
        _, _, done = task.step(rotor_speeds)
        to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_write[ii])
        writer.writerow(to_write)
        if done:
            break

# %% [markdown]
# Run the code cell below to visualize how the position of the quadcopter evolved during the simulation.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(results['time'], results['x'], label='x')
plt.plot(results['time'], results['y'], label='y')
plt.plot(results['time'], results['z'], label='z')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# The next code cell visualizes the velocity of the quadcopter.

# %%
plt.plot(results['time'], results['x_velocity'], label='x_hat')
plt.plot(results['time'], results['y_velocity'], label='y_hat')
plt.plot(results['time'], results['z_velocity'], label='z_hat')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Next, you can plot the Euler angles (the rotation of the quadcopter over the $x$-, $y$-, and $z$-axes),

# %%
plt.plot(results['time'], results['phi'], label='phi')
plt.plot(results['time'], results['theta'], label='theta')
plt.plot(results['time'], results['psi'], label='psi')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# before plotting the velocities (in radians per second) corresponding to each of the Euler angles.

# %%
plt.plot(results['time'], results['phi_velocity'], label='phi_velocity')
plt.plot(results['time'], results['theta_velocity'], label='theta_velocity')
plt.plot(results['time'], results['psi_velocity'], label='psi_velocity')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Finally, you can use the code cell below to print the agent's choice of actions.

# %%
plt.plot(results['time'], results['rotor_speed1'], label='Rotor 1 revolutions / second')
plt.plot(results['time'], results['rotor_speed2'], label='Rotor 2 revolutions / second')
plt.plot(results['time'], results['rotor_speed3'], label='Rotor 3 revolutions / second')
plt.plot(results['time'], results['rotor_speed4'], label='Rotor 4 revolutions / second')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# When specifying a task, you will derive the environment state from the simulator.  Run the code cell below to print the values of the following variables at the end of the simulation:
# - `task.sim.pose` (the position of the quadcopter in ($x,y,z$) dimensions and the Euler angles),
# - `task.sim.v` (the velocity of the quadcopter in ($x,y,z$) dimensions), and
# - `task.sim.angular_v` (radians/second for each of the three Euler angles).

# %%
# the pose, velocity, and angular velocity of the quadcopter at the end of the episode
print(task.sim.pose)
print(task.sim.v)
print(task.sim.angular_v)

a=np.concatenate((task.sim.pose, task.sim.v, task.sim.angular_v),axis=0)
print(a)
# Out:
# [22.56461692  2.62757314 25.07277053  6.11383534  5.53575856  0.        ]
# [13.50150861 -0.12190016  0.78369893]
# [-0.05526847 -0.08008425  0.        ]
# [22.56461692  2.62757314 25.07277053  6.11383534  5.53575856  0.
#  13.50150861 -0.12190016  0.78369893 -0.05526847 -0.08008425  0.        ]

# %% [markdown]
# In the sample task in `task.py`, we use the 6-dimensional pose of the quadcopter to construct the state of the environment at each timestep.  However, when amending the task for your purposes, you are welcome to expand the size of the state vector by including the velocity information.  You can use any combination of the pose, velocity, and angular velocity - feel free to tinker here, and construct the state to suit your task.
#
# ## The Task
#
# A sample task has been provided for you in `task.py`.  Open this file in a new window now.
#
# The `__init__()` method is used to initialize several variables that are needed to specify the task.
# - The simulator is initialized as an instance of the `PhysicsSim` class (from `physics_sim.py`).
# - Inspired by the methodology in the original DDPG paper, we make use of action repeats.  For each timestep of the agent, we step the simulation `action_repeats` timesteps.  If you are not familiar with action repeats, please read the **Results** section in [the DDPG paper](https://arxiv.org/abs/1509.02971).
# - We set the number of elements in the state vector.  For the sample task, we only work with the 6-dimensional pose information.  To set the size of the state (`state_size`), we must take action repeats into account.
# - The environment will always have a 4-dimensional action space, with one entry for each rotor (`action_size=4`). You can set the minimum (`action_low`) and maximum (`action_high`) values of each entry here.
# - The sample task in this provided file is for the agent to reach a target position.  We specify that target position as a variable.
#
# The `reset()` method resets the simulator.  The agent should call this method every time the episode ends.  You can see an example of this in the code cell below.
#
# The `step()` method is perhaps the most important.  It accepts the agent's choice of action `rotor_speeds`, which is used to prepare the next state to pass on to the agent.  Then, the reward is computed from `get_reward()`.  The episode is considered done if the time limit has been exceeded, or the quadcopter has travelled outside of the bounds of the simulation.
#
# In the next section, you will learn how to test the performance of an agent on this task.

# %% [markdown]
# ## The Agent
#
# The sample agent given in `agents/policy_search.py` uses a very simplistic linear policy to directly compute the action vector as a dot product of the state vector and a matrix of weights. Then, it randomly perturbs the parameters by adding some Gaussian noise, to produce a different policy. Based on the average reward obtained in each episode (`score`), it keeps track of the best set of parameters found so far, how the score is changing, and accordingly tweaks a scaling factor to widen or tighten the noise.
#
# Run the code cell below to see how the agent performs on the sample task.

# %%
import sys
import pandas as pd
from agents.policy_search import PolicySearch_Agent
from task import Task
import numpy as np

num_episodes = 1000
target_pos = np.array([0., 0., 10.])
task = Task(target_pos=target_pos)
agent = PolicySearch_Agent(task) 

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(reward, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                i_episode, agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
            break
        
    sys.stdout.flush()
# Out:
# Episode = 1000, score = 284.984 (best = 300.731), noise_scale = 3.2555

# %%
reward
# Out:
# 32.934324924947276

# %% [markdown]
# This agent should perform very poorly on this task.  And that's where you come in!

# %% [markdown]
# ## Define the Task, Design the Agent, and Train Your Agent!
#
# Amend `task.py` to specify a task of your choosing.  If you're unsure what kind of task to specify, you may like to teach your quadcopter to takeoff, hover in place, land softly, or reach a target pose.
#
# After specifying your task, use the sample agent in `agents/policy_search.py` as a template to define your own agent in `agents/agent.py`.  You can borrow whatever you need from the sample agent, including ideas on how you might modularize your code (using helper methods like `act()`, `learn()`, `reset_episode()`, etc.).
#
# Note that it is **highly unlikely** that the first agent and task that you specify will learn well.  You will likely have to tweak various hyperparameters and the reward function for your task until you arrive at reasonably good behavior.
#
# As you develop your agent, it's important to keep an eye on how it's performing. Use the code above as inspiration to build in a mechanism to log/save the total rewards obtained in each episode to file.  If the episode rewards are gradually increasing, this is an indication that your agent is learning.

# %%
## TODO: Train your agent here.
import sys
import numpy as np
from agents.agent import DDPGAgent
import pandas as pd
from task import Task

num_episodes = 1000
target_pos = np.array([0., 0., 100.])
runtime = 10
task = Task(target_pos=target_pos, runtime = runtime)
agent = DDPGAgent(task) 
score = 0.0
best_score = -100

labels = ['Episode', 'Score', 'Best Score']
results = {x : [] for x in labels}

x_pos = []
y_pos = []
z_pos = []
rewards = []

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    x_pos_temp = []
    y_pos_temp = []
    z_pos_temp = []
    
    while True:
        x_pos_temp.append(task.sim.pose[0])
        y_pos_temp.append(task.sim.pose[1])
        z_pos_temp.append(task.sim.pose[2])
        
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        
        score += reward
        best_score = max(best_score, score)

        agent.step(action, reward, next_state, done)
        state = next_state
        
        if done:
            rewards.append(score)

            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}) position = {} {} {}".format(
                i_episode, score, best_score, 
                  round(task.sim.pose[:3][0],1),
                  round(task.sim.pose[:3][1],1),
                  round(task.sim.pose[:3][2],1), end=""))  # [debug]
            x_pos.append(x_pos_temp)
            y_pos.append(y_pos_temp)
            z_pos.append(z_pos_temp)   
            to_write = [i_episode] + [score] + [best_score]
            for ii in range(len(labels)):
                results[labels[ii]].append(to_write[ii])
            break
    sys.stdout.flush()
# Out:
# Episode =    1, score = -29.966 (best =  -1.860) position = -8.0 -0.7 0.0
# Episode =    2, score = -59.936 (best =  -1.860) position = -8.0 -0.7 0.0
# Episode =    3, score = -89.831 (best =  -1.860) position = -7.0 0.1 0.0
# Episode =    4, score = -108.090 (best =  -1.860) position = 0.5 0.1 0.0
# Episode =    5, score = -126.261 (best =  -1.860) position = -0.3 0.0 0.0
# Episode =    6, score = -144.453 (best =  -1.860) position = -0.5 0.0 0.0
# Episode =    7, score = -173.961 (best =  -1.860) position = -0.7 -0.6 0.0
# Episode =    8, score = -199.845 (best =  -1.860) position = -0.3 -2.7 0.0
# Episode =    9, score = -246.471 (best =  -1.860) position = -6.9 -28.4 0.0
# Episode =   10, score = -370.226 (best =  -1.860) position = -10.3 -54.7 0.0
# Episode =   11, score = -415.885 (best =  -1.860) position = -12.0 -6.3 0.0
# Episode =   12, score = -423.296 (best =  -1.860) position = -5.1 3.7 0.0
# Episode =   13, score = -433.697 (best =  -1.860) position = -8.0 0.3 0.0
# Episode =   14, score = -454.929 (best =  -1.860) position = 5.9 -0.1 0.0
# Episode =   15, score = -481.171 (best =  -1.860) position = -6.5 1.8 0.0
# Episode =   16, score = -495.177 (best =  -1.860) position = 3.3 1.9 0.0
# Episode =   17, score = -503.647 (best =  -1.860) position = 4.1 -2.0 0.0
# Episode =   18, score = -513.255 (best =  -1.860) position = 2.1 -2.6 0.0
# Episode =   19, score = -521.897 (best =  -1.860) position = 1.1 -7.4 0.0
# Episode =   20, score = -539.473 (best =  -1.860) position = -4.6 5.3 0.0
# Episode =   21, score = -543.305 (best =  -1.860) position = -0.8 0.6 0.0
# Episode =   22, score = -573.617 (best =  -1.860) position = -4.4 -0.8 0.0
# Episode =   23, score = -583.254 (best =  -1.860) position = 4.3 4.0 0.0
# Episode =   24, score = -622.717 (best =  -1.860) position = -3.9 24.8 0.0
# Episode =   25, score = -643.384 (best =  -1.860) position = -9.5 0.7 0.0
# Episode =   26, score = -651.856 (best =  -1.860) position = 1.5 2.2 0.0
# Episode =   27, score = -663.461 (best =  -1.860) position = -0.8 0.3 0.0
# Episode =   28, score = -682.841 (best =  -1.860) position = 5.0 -1.9 0.0
# Episode =   29, score = -693.516 (best =  -1.860) position = -4.2 0.9 0.0
# Episode =   30, score = -726.374 (best =  -1.860) position = 4.7 1.1 0.0
# Episode =   31, score = -744.030 (best =  -1.860) position = -2.2 0.3 0.0
# Episode =   32, score = -801.772 (best =  -1.860) position = -5.3 0.0 0.0
# Episode =   33, score = -837.842 (best =  -1.860) position = -2.4 0.0 0.0
# Episode =   34, score = -874.121 (best =  -1.860) position = -5.4 0.0 0.0
# Episode =   35, score = -916.873 (best =  -1.860) position = -1.6 0.0 0.0
# Episode =   36, score = -981.181 (best =  -1.860) position = 4.3 0.0 0.0
# Episode =   37, score = -1012.301 (best =  -1.860) position = -10.0 0.0 0.0
# Episode =   38, score = -1018.147 (best =  -1.860) position = -2.5 0.0 0.0
# Episode =   39, score = -1028.274 (best =  -1.860) position = 2.6 0.0 0.0
# Episode =   40, score = -1089.753 (best =  -1.860) position = 1.5 0.0 0.0
# Episode =   41, score = -1087.910 (best =  -1.860) position = 0.5 0.0 0.0
# Episode =   42, score = -1118.995 (best =  -1.860) position = -0.4 0.0 0.0
# Episode =   43, score = -1116.011 (best =  -1.860) position = 1.6 0.0 0.0
# Episode =   44, score = -1106.962 (best =  -1.860) position = 0.0 0.0 0.0
# Episode =   45, score = -1117.313 (best =  -1.860) position = -3.9 0.0 0.0
# Episode =   46, score = -1145.455 (best =  -1.860) position = -15.9 0.0 0.0
# Episode =   47, score = -1196.659 (best =  -1.860) position = -17.7 0.0 0.0
# Episode =   48, score = -1235.292 (best =  -1.860) position = -17.5 0.0 0.0
# Episode =   49, score = -1293.289 (best =  -1.860) position = -23.4 0.0 0.0
# Episode =   50, score = -1278.644 (best =  -1.860) position = 0.4 0.1 0.0
# Episode =   51, score = -1289.526 (best =  -1.860) position = 2.3 0.0 0.0
# Episode =   52, score = -1332.443 (best =  -1.860) position = -8.1 0.7 0.0
# Episode =   53, score = -1346.203 (best =  -1.860) position = 0.6 3.4 0.0
# Episode =   54, score = -1388.554 (best =  -1.860) position = -22.0 3.0 0.0
# Episode =   55, score = -1412.499 (best =  -1.860) position = -14.6 2.0 0.0
# Episode =   56, score = -1426.064 (best =  -1.860) position = 0.7 2.0 0.0
# Episode =   57, score = -1447.692 (best =  -1.860) position = -5.1 2.5 0.0
# Episode =   58, score = -1461.695 (best =  -1.860) position = -0.6 0.4 0.0
# Episode =   59, score = -1475.824 (best =  -1.860) position = -7.9 3.8 0.0
# Episode =   60, score = -1509.754 (best =  -1.860) position = 11.3 2.4 0.0
# Episode =   61, score = -1546.237 (best =  -1.860) position = 1.1 1.4 0.0
# Episode =   62, score = -1574.123 (best =  -1.860) position = -0.7 1.7 0.0
# Episode =   63, score = -1607.305 (best =  -1.860) position = -3.1 3.2 0.0
# Episode =   64, score = -1638.790 (best =  -1.860) position = -5.0 4.4 0.0
# Episode =   65, score = -1657.527 (best =  -1.860) position = -12.7 3.0 0.0
# Episode =   66, score = -1690.768 (best =  -1.860) position = -1.9 2.0 0.0
# Episode =   67, score = -1714.239 (best =  -1.860) position = -1.0 1.6 0.0
# Episode =   68, score = -1747.284 (best =  -1.860) position = -4.3 2.5 0.0
# Episode =   69, score = -1778.646 (best =  -1.860) position = -5.4 3.3 0.0
# Episode =   70, score = -1818.237 (best =  -1.860) position = 2.2 -1.7 0.0
# Episode =   71, score = -1869.311 (best =  -1.860) position = 4.9 -3.1 0.0
# Episode =   72, score = -1900.701 (best =  -1.860) position = 2.1 -0.6 0.0
# Episode =   73, score = -1941.599 (best =  -1.860) position = -6.5 5.7 0.0
# Episode =   74, score = -1988.262 (best =  -1.860) position = 5.9 -2.8 0.0
# Episode =   75, score = -2039.202 (best =  -1.860) position = 3.6 -2.5 0.0
# Episode =   76, score = -2066.878 (best =  -1.860) position = -0.9 0.5 0.0
# Episode =   77, score = -2101.156 (best =  -1.860) position = 3.3 -1.5 0.0
# Episode =   78, score = -2134.336 (best =  -1.860) position = -1.4 2.0 0.0
# Episode =   79, score = -2155.434 (best =  -1.860) position = 2.4 1.3 0.0
# Episode =   80, score = -2185.266 (best =  -1.860) position = 6.1 -0.2 0.0
# Episode =   81, score = -2207.445 (best =  -1.860) position = 5.3 0.0 0.0
# Episode =   82, score = -2247.127 (best =  -1.860) position = 6.9 -0.6 0.0
# Episode =   83, score = -2261.268 (best =  -1.860) position = 3.5 -0.1 0.0
# Episode =   84, score = -2283.900 (best =  -1.860) position = -3.4 5.3 0.0
# Episode =   85, score = -2288.574 (best =  -1.860) position = 9.6 -2.3 0.0
# Episode =   86, score = -2310.666 (best =  -1.860) position = 6.4 -0.3 0.0
# Episode =   87, score = -2320.079 (best =  -1.860) position = -2.3 -3.3 0.0
# Episode =   88, score = -2347.301 (best =  -1.860) position = 1.7 -4.4 0.0
# Episode =   89, score = -2367.567 (best =  -1.860) position = -0.9 2.1 0.0
# Episode =   90, score = -2402.489 (best =  -1.860) position = -4.5 3.6 0.0
# Episode =   91, score = -2425.346 (best =  -1.860) position = -4.0 1.9 0.0
# Episode =   92, score = -2460.209 (best =  -1.860) position = -6.1 -3.6 0.0
# Episode =   93, score = -2489.714 (best =  -1.860) position = 3.2 -3.7 0.0
# Episode =   94, score = -2508.252 (best =  -1.860) position = -1.6 -3.2 0.0
# Episode =   95, score = -2540.957 (best =  -1.860) position = 0.3 -4.5 0.0
# Episode =   96, score = -2558.633 (best =  -1.860) position = -8.3 -0.7 0.0
# Episode =   97, score = -2594.533 (best =  -1.860) position = 5.6 -1.8 0.0
# Episode =   98, score = -2605.937 (best =  -1.860) position = -3.0 4.1 0.0
# Episode =   99, score = -2633.722 (best =  -1.860) position = -2.3 -3.2 0.0
# Episode =  100, score = -2650.120 (best =  -1.860) position = 5.2 -0.6 0.0
# Episode =  101, score = -2692.932 (best =  -1.860) position = -4.7 0.3 0.0
# Episode =  102, score = -2726.732 (best =  -1.860) position = 6.0 -3.7 0.0
# Episode =  103, score = -2760.642 (best =  -1.860) position = 5.8 -3.6 0.0
# Episode =  104, score = -2798.734 (best =  -1.860) position = 1.8 -3.3 0.0
# Episode =  105, score = -2822.291 (best =  -1.860) position = 2.7 -0.1 0.0
# Episode =  106, score = -2845.905 (best =  -1.860) position = 1.7 5.8 0.0
# Episode =  107, score = -2876.456 (best =  -1.860) position = 3.8 -2.7 0.0
# Episode =  108, score = -2912.491 (best =  -1.860) position = 6.1 -1.8 0.0
# Episode =  109, score = -2926.082 (best =  -1.860) position = 1.6 2.0 0.0
# Episode =  110, score = -2947.568 (best =  -1.860) position = -4.6 3.0 0.0
# Episode =  111, score = -2978.838 (best =  -1.860) position = -3.3 3.1 0.0
# Episode =  112, score = -2994.521 (best =  -1.860) position = -1.9 1.7 0.0
# Episode =  113, score = -3008.086 (best =  -1.860) position = 1.9 2.0 0.0
# Episode =  114, score = -3021.653 (best =  -1.860) position = 0.6 2.0 0.0
# Episode =  115, score = -3044.886 (best =  -1.860) position = -5.0 4.7 0.0
# Episode =  116, score = -3056.353 (best =  -1.860) position = 2.1 0.6 0.0
# Episode =  117, score = -3087.424 (best =  -1.860) position = -2.5 2.9 0.0
# Episode =  118, score = -3120.336 (best =  -1.860) position = 1.2 2.4 0.0
# Episode =  119, score = -3133.993 (best =  -1.860) position = 1.4 2.4 0.0
# Episode =  120, score = -3147.587 (best =  -1.860) position = 1.3 2.0 0.0
# Episode =  121, score = -3161.175 (best =  -1.860) position = 1.9 2.0 0.0
# Episode =  122, score = -3174.745 (best =  -1.860) position = -4.6 2.0 0.0
# Episode =  123, score = -3188.284 (best =  -1.860) position = 0.6 2.0 0.0
# Episode =  124, score = -3201.859 (best =  -1.860) position = 0.7 2.0 0.0
# Episode =  125, score = -3215.473 (best =  -1.860) position = -1.4 2.0 0.0
# Episode =  126, score = -3229.003 (best =  -1.860) position = 1.8 1.9 0.0
# Episode =  127, score = -3242.584 (best =  -1.860) position = -0.9 2.0 0.0
# Episode =  128, score = -3256.114 (best =  -1.860) position = 2.2 1.9 0.0
# Episode =  129, score = -3269.698 (best =  -1.860) position = -1.3 2.0 0.0
# Episode =  130, score = -3283.227 (best =  -1.860) position = -1.4 1.9 0.0
# Episode =  131, score = -3296.838 (best =  -1.860) position = -0.8 2.0 0.0
# Episode =  132, score = -3310.369 (best =  -1.860) position = -1.7 1.9 0.0
# Episode =  133, score = -3323.941 (best =  -1.860) position = 0.9 2.0 0.0
# Episode =  134, score = -3337.555 (best =  -1.860) position = -1.1 2.0 0.0
# Episode =  135, score = -3351.140 (best =  -1.860) position = 1.2 2.0 0.0
# Episode =  136, score = -3364.694 (best =  -1.860) position = -1.8 2.0 0.0
# Episode =  137, score = -3378.258 (best =  -1.860) position = -0.1 2.0 0.0
# Episode =  138, score = -3391.795 (best =  -1.860) position = -1.3 1.9 0.0
# Episode =  139, score = -3405.365 (best =  -1.860) position = 1.3 2.0 0.0
# Episode =  140, score = -3418.919 (best =  -1.860) position = 1.1 2.0 0.0
# Episode =  141, score = -3432.529 (best =  -1.860) position = 0.4 2.0 0.0
# Episode =  142, score = -3446.158 (best =  -1.860) position = -5.7 2.1 0.0
# Episode =  143, score = -3459.729 (best =  -1.860) position = 3.4 2.0 0.0
# Episode =  144, score = -3483.365 (best =  -1.860) position = -9.0 2.0 0.0
# Episode =  145, score = -3496.937 (best =  -1.860) position = 1.6 2.0 0.0
# Episode =  146, score = -3515.576 (best =  -1.860) position = -24.0 1.8 0.0
# Episode =  147, score = -3532.417 (best =  -1.860) position = 16.1 1.8 0.0
# Episode =  148, score = -3546.026 (best =  -1.860) position = 0.5 2.1 0.0
# Episode =  149, score = -3559.639 (best =  -1.860) position = 1.7 2.0 0.0
# Episode =  150, score = -3573.233 (best =  -1.860) position = -3.0 2.0 0.0
# Episode =  151, score = -3597.469 (best =  -1.860) position = -13.1 3.3 0.0
# Episode =  152, score = -3611.038 (best =  -1.860) position = 0.3 2.0 0.0
# Episode =  153, score = -3635.946 (best =  -1.860) position = 3.6 5.2 0.0
# Episode =  154, score = -3680.635 (best =  -1.860) position = -5.4 2.1 0.0
# Episode =  155, score = -3694.213 (best =  -1.860) position = -1.1 2.0 0.0
# Episode =  156, score = -3716.590 (best =  -1.860) position = -13.4 2.0 0.0
# Episode =  157, score = -3733.749 (best =  -1.860) position = 18.3 1.7 0.0
# Episode =  158, score = -3747.333 (best =  -1.860) position = 1.0 2.0 0.0
# Episode =  159, score = -3776.078 (best =  -1.860) position = -25.2 1.8 0.0
# Episode =  160, score = -3789.683 (best =  -1.860) position = 2.8 2.0 0.0
# Episode =  161, score = -3803.240 (best =  -1.860) position = -0.1 2.0 0.0
# Episode =  162, score = -3817.691 (best =  -1.860) position = 11.0 -0.4 0.0
# Episode =  163, score = -3831.224 (best =  -1.860) position = 0.4 1.9 0.0
# Episode =  164, score = -3859.339 (best =  -1.860) position = -24.1 1.8 0.0
# Episode =  165, score = -3872.911 (best =  -1.860) position = 0.5 2.0 0.0
# Episode =  166, score = -3896.965 (best =  -1.860) position = -13.1 1.4 0.0
# Episode =  167, score = -3910.851 (best =  -1.860) position = 4.4 -0.3 0.0
# Episode =  168, score = -3934.486 (best =  -1.860) position = -7.6 2.0 0.0
# Episode =  169, score = -3948.090 (best =  -1.860) position = -4.1 2.0 0.0
# Episode =  170, score = -3963.866 (best =  -1.860) position = 4.0 3.7 0.0
# Episode =  171, score = -3977.462 (best =  -1.860) position = 3.3 2.0 0.0
# Episode =  172, score = -3991.029 (best =  -1.860) position = 2.3 2.0 0.0
# Episode =  173, score = -4012.608 (best =  -1.860) position = -3.1 4.6 0.0
# Episode =  174, score = -4026.184 (best =  -1.860) position = -1.0 2.0 0.0
# Episode =  175, score = -4044.065 (best =  -1.860) position = -21.3 1.7 0.0
# Episode =  176, score = -4057.594 (best =  -1.860) position = 1.1 1.9 0.0
# Episode =  177, score = -4071.183 (best =  -1.860) position = 1.7 2.0 0.0
# Episode =  178, score = -4084.709 (best =  -1.860) position = 2.9 1.9 0.0
# Episode =  179, score = -4098.257 (best =  -1.860) position = -1.0 2.0 0.0
# Episode =  180, score = -4111.790 (best =  -1.860) position = 0.9 1.9 0.0
# Episode =  181, score = -4150.343 (best =  -1.860) position = -25.9 1.9 0.0
# Episode =  182, score = -4163.921 (best =  -1.860) position = 3.0 2.0 0.0
# Episode =  183, score = -4177.543 (best =  -1.860) position = 0.5 2.1 0.0
# Episode =  184, score = -4191.100 (best =  -1.860) position = 1.0 2.0 0.0
# Episode =  185, score = -4209.645 (best =  -1.860) position = -25.3 2.0 0.0
# Episode =  186, score = -4223.208 (best =  -1.860) position = 1.4 2.0 0.0
# Episode =  187, score = -4236.829 (best =  -1.860) position = 2.7 2.0 0.0
# Episode =  188, score = -4250.435 (best =  -1.860) position = -1.2 2.0 0.0
# Episode =  189, score = -4264.018 (best =  -1.860) position = -0.8 2.0 0.0
# Episode =  190, score = -4277.574 (best =  -1.860) position = 2.8 2.0 0.0
# Episode =  191, score = -4301.137 (best =  -1.860) position = -8.1 2.0 0.0
# Episode =  192, score = -4311.122 (best =  -1.860) position = 2.5 2.3 0.0
# Episode =  193, score = -4324.653 (best =  -1.860) position = 2.4 1.9 0.0
# Episode =  194, score = -4352.649 (best =  -1.860) position = 13.9 2.9 0.0
# Episode =  195, score = -4387.673 (best =  -1.860) position = -22.8 2.0 0.0
# Episode =  196, score = -4401.269 (best =  -1.860) position = 3.8 2.0 0.0
# Episode =  197, score = -4414.850 (best =  -1.860) position = 0.1 2.0 0.0
# Episode =  198, score = -4443.319 (best =  -1.860) position = -24.5 1.9 0.0
# Episode =  199, score = -4472.009 (best =  -1.860) position = -25.7 1.9 0.0
# Episode =  200, score = -4499.466 (best =  -1.860) position = 8.5 2.5 0.0
# Episode =  201, score = -4512.981 (best =  -1.860) position = -2.4 1.9 0.0
# Episode =  202, score = -4553.638 (best =  -1.860) position = 0.7 2.0 0.0
# Episode =  203, score = -4567.223 (best =  -1.860) position = -4.2 2.0 0.0
# Episode =  204, score = -4595.284 (best =  -1.860) position = -24.1 1.8 0.0
# Episode =  205, score = -4608.914 (best =  -1.860) position = -0.4 2.0 0.0
# Episode =  206, score = -4622.505 (best =  -1.860) position = 0.2 2.0 0.0
# Episode =  207, score = -4636.070 (best =  -1.860) position = 0.7 2.0 0.0
# Episode =  208, score = -4649.646 (best =  -1.860) position = 0.3 2.0 0.0
# Episode =  209, score = -4673.215 (best =  -1.860) position = -9.2 1.9 0.0
# Episode =  210, score = -4686.747 (best =  -1.860) position = 1.4 1.9 0.0
# Episode =  211, score = -4700.246 (best =  -1.860) position = -0.7 1.9 0.0
# Episode =  212, score = -4713.821 (best =  -1.860) position = -5.0 2.0 0.0
# Episode =  213, score = -4727.383 (best =  -1.860) position = 4.8 2.0 0.0
# Episode =  214, score = -4740.980 (best =  -1.860) position = 1.3 2.0 0.0
# Episode =  215, score = -4764.623 (best =  -1.860) position = -9.0 2.0 0.0
# Episode =  216, score = -4778.211 (best =  -1.860) position = -0.8 2.0 0.0
# Episode =  217, score = -4791.741 (best =  -1.860) position = 2.0 1.9 0.0
# Episode =  218, score = -4805.297 (best =  -1.860) position = 1.0 1.9 0.0
# Episode =  219, score = -4818.829 (best =  -1.860) position = 0.2 1.9 0.0
# Episode =  220, score = -4846.544 (best =  -1.860) position = 11.0 2.6 0.0
# Episode =  221, score = -4871.263 (best =  -1.860) position = -20.9 2.0 0.0
# Episode =  222, score = -4884.776 (best =  -1.860) position = 1.9 1.9 0.0
# Episode =  223, score = -4898.368 (best =  -1.860) position = 1.3 2.0 0.0
# Episode =  224, score = -4911.943 (best =  -1.860) position = 1.8 2.0 0.0
# Episode =  225, score = -4936.116 (best =  -1.860) position = -16.8 1.9 0.0
# Episode =  226, score = -4959.889 (best =  -1.860) position = -12.9 2.0 0.0
# Episode =  227, score = -4983.469 (best =  -1.860) position = -6.8 2.0 0.0
# Episode =  228, score = -4997.055 (best =  -1.860) position = 0.6 2.0 0.0
# Episode =  229, score = -5010.652 (best =  -1.860) position = -0.1 2.0 0.0
# Episode =  230, score = -5034.427 (best =  -1.860) position = -14.0 1.9 0.0
# Episode =  231, score = -5048.013 (best =  -1.860) position = -1.7 2.0 0.0
# Episode =  232, score = -5061.592 (best =  -1.860) position = 1.6 2.0 0.0
# Episode =  233, score = -5075.189 (best =  -1.860) position = -1.5 2.0 0.0
# Episode =  234, score = -5088.768 (best =  -1.860) position = -2.2 2.0 0.0
# Episode =  235, score = -5112.796 (best =  -1.860) position = -16.8 1.9 0.0
# Episode =  236, score = -5136.721 (best =  -1.860) position = -15.4 2.0 0.0
# Episode =  237, score = -5150.270 (best =  -1.860) position = -2.6 2.0 0.0
# Episode =  238, score = -5163.876 (best =  -1.860) position = -6.2 2.0 0.0
# Episode =  239, score = -5177.480 (best =  -1.860) position = -0.6 2.0 0.0
# Episode =  240, score = -5204.203 (best =  -1.860) position = -21.0 -0.0 0.0
# Episode =  241, score = -5269.800 (best =  -1.860) position = -62.9 1.5 0.0
# Episode =  242, score = -5289.182 (best =  -1.860) position = -14.7 0.2 0.0
# Episode =  243, score = -5416.424 (best =  -1.860) position = -30.6 28.2 0.0
# Episode =  244, score = -5452.319 (best =  -1.860) position = -18.3 0.2 0.0
# Episode =  245, score = -5513.005 (best =  -1.860) position = -32.8 -18.2 0.0
# Episode =  246, score = -5511.478 (best =  -1.860) position = 59.1 125.9 300.0
# Episode =  247, score = -2359.381 (best =  -1.860) position = 67.2 147.3 300.0
# Episode =  248, score = -2420.961 (best =  -1.860) position = 0.4 -2.0 0.0
# Episode =  249, score = -2417.886 (best =  -1.860) position = -72.5 48.3 0.0
# Episode =  250, score = -2657.301 (best =  -1.860) position = -150.0 11.6 143.2
# Episode =  251, score = -2748.505 (best =  -1.860) position = -3.0 150.0 300.0
# Episode =  252, score = -2895.702 (best =  -1.860) position = -150.0 -45.3 73.7
# Episode =  253, score = -2975.967 (best =  -1.860) position = -105.7 82.0 300.0
# Episode =  254, score = -2947.329 (best =  -1.860) position = 55.0 -5.8 300.0
# Episode =  255, score = -2208.423 (best =  -1.860) position = 50.4 -20.3 300.0
# Episode =  256, score = -2343.770 (best =  -1.860) position = 150.0 -53.7 274.7
# Episode =  257, score = -993.089 (best =  -1.860) position = 38.1 27.0 300.0
# Episode =  258, score = -1180.945 (best =  -1.860) position = 73.8 -150.0 97.1
# Episode =  259, score = -1221.238 (best =  -1.860) position = 90.5 45.0 300.0
# Episode =  260, score = -410.216 (best =  -1.860) position = -19.2 150.0 300.0
# Episode =  261, score = 2932.241 (best = 3017.457) position = 11.9 14.4 300.0
# Episode =  262, score = 4558.778 (best = 4866.973) position = -150.0 -20.4 138.4
# Episode =  263, score = 4597.416 (best = 4866.973) position = 130.2 41.0 300.0
# Episode =  264, score = 4305.259 (best = 4866.973) position = -4.0 123.5 300.0
# Episode =  265, score = 4312.060 (best = 4866.973) position = -70.7 58.6 300.0
# Episode =  266, score = 5916.585 (best = 6246.940) position = 150.0 79.9 286.2
# Episode =  267, score = 5890.982 (best = 6246.940) position = -150.0 77.5 193.5
# Episode =  268, score = 6469.483 (best = 6599.469) position = 91.1 77.7 300.0
# Episode =  269, score = 6068.385 (best = 6599.469) position = 110.0 117.9 184.4
# Episode =  270, score = 5659.168 (best = 6599.469) position = -116.3 -75.1 0.0
# Episode =  271, score = 8235.897 (best = 8378.076) position = -128.0 150.0 300.0
# Episode =  272, score = 8191.742 (best = 8378.076) position = 6.6 -150.0 166.6
# Episode =  273, score = 8027.986 (best = 8378.076) position = -54.3 -150.0 153.0
# Episode =  274, score = 7989.741 (best = 8378.076) position = 148.0 -150.0 278.4
# Episode =  275, score = 10264.706 (best = 10632.102) position = -138.3 -101.0 97.3
# Episode =  276, score = 9980.968 (best = 10632.102) position = -32.3 -128.3 0.0
# Episode =  277, score = 11501.205 (best = 11605.200) position = -39.0 66.0 300.0
# Episode =  278, score = 11477.951 (best = 11605.200) position = -7.1 0.0 0.0
# Episode =  279, score = 11445.049 (best = 11605.200) position = -7.0 0.0 0.0
# Episode =  280, score = 11421.375 (best = 11605.200) position = -7.0 0.7 0.0
# Episode =  281, score = 11482.792 (best = 11605.200) position = -22.8 1.9 90.2
# Episode =  282, score = 11542.603 (best = 11605.200) position = -23.0 -6.4 90.3
# Episode =  283, score = 11602.788 (best = 11605.200) position = -22.5 2.4 89.8
# Episode =  284, score = 11663.988 (best = 11663.988) position = -22.6 -2.0 90.3
# Episode =  285, score = 11722.916 (best = 11722.916) position = -23.4 -10.8 90.9
# Episode =  286, score = 11783.254 (best = 11783.254) position = -23.0 -5.7 90.4
# Episode =  287, score = 11841.853 (best = 11841.853) position = -23.3 -11.9 90.7
# Episode =  288, score = 11876.370 (best = 11876.370) position = -21.6 32.7 86.6
# Episode =  289, score = 11902.987 (best = 11902.987) position = -24.1 -38.8 89.7
# Episode =  290, score = 11952.784 (best = 11952.784) position = -23.4 -24.0 90.1
# Episode =  291, score = 11998.478 (best = 11998.478) position = -22.2 24.1 87.8
# Episode =  292, score = 12040.882 (best = 12040.882) position = -23.8 -28.6 90.2
# Episode =  293, score = 12102.961 (best = 12102.961) position = -22.7 0.1 90.2
# Episode =  294, score = 12139.299 (best = 12139.299) position = -21.8 29.3 87.1
# Episode =  295, score = 12196.641 (best = 12196.641) position = -23.3 -12.6 90.7
# Episode =  296, score = 12256.760 (best = 12256.760) position = -22.8 0.8 90.0
# Episode =  297, score = 12304.288 (best = 12304.288) position = -22.2 21.3 88.1
# Episode =  298, score = 12359.336 (best = 12359.336) position = -22.3 17.2 88.9
# Episode =  299, score = 12408.836 (best = 12408.836) position = -22.1 16.4 88.7
# Episode =  300, score = 12469.299 (best = 12469.299) position = -22.8 2.8 90.1
# Episode =  301, score = 12531.321 (best = 12531.321) position = -23.1 -6.4 90.6
# Episode =  302, score = 12532.483 (best = 12532.483) position = -24.7 -49.4 88.5
# Episode =  303, score = 12584.072 (best = 12584.072) position = -23.1 -21.5 89.9
# Episode =  304, score = 12639.256 (best = 12639.256) position = -23.1 -17.8 90.2
# Episode =  305, score = 12694.479 (best = 12694.479) position = -23.1 -15.4 90.0
# Episode =  306, score = 12737.839 (best = 12737.839) position = -23.6 -30.9 89.9
# Episode =  307, score = 12767.104 (best = 12767.104) position = -21.6 33.0 86.5
# Episode =  308, score = 12812.428 (best = 12812.428) position = -22.0 25.4 87.9
# Episode =  309, score = 12874.306 (best = 12874.306) position = -22.6 -1.3 90.2
# Episode =  310, score = 12931.414 (best = 12931.414) position = -22.6 13.4 89.3
# Episode =  311, score = 12969.088 (best = 12969.088) position = -23.9 -30.6 90.1
# Episode =  312, score = 13029.181 (best = 13029.181) position = -23.1 -7.6 90.3
# Episode =  313, score = 13073.812 (best = 13073.812) position = -21.9 23.7 87.8
# Episode =  314, score = 13130.735 (best = 13130.735) position = -23.1 -11.3 90.6
# Episode =  315, score = 13175.681 (best = 13175.681) position = -23.6 -29.6 90.0
# Episode =  316, score = 13236.301 (best = 13236.301) position = -22.9 -3.6 90.4
# Episode =  317, score = 13297.899 (best = 13297.899) position = -22.8 -0.2 90.2
# Episode =  318, score = 13358.525 (best = 13358.525) position = -22.9 -4.2 90.3
# Episode =  319, score = 13408.144 (best = 13408.144) position = -23.5 -24.5 90.2
# Episode =  320, score = 13466.330 (best = 13466.330) position = -22.4 7.6 89.5
# Episode =  321, score = 13529.376 (best = 13529.376) position = -23.2 -5.5 90.8
# Episode =  322, score = 13578.938 (best = 13578.938) position = -22.0 18.9 88.4
# Episode =  323, score = 13637.146 (best = 13637.146) position = -23.3 -9.5 90.7
# Episode =  324, score = 13695.289 (best = 13695.289) position = -22.3 10.5 89.5
# Episode =  325, score = 13755.960 (best = 13755.960) position = -22.9 -9.3 90.5
# Episode =  326, score = 13816.676 (best = 13816.676) position = -23.2 -11.5 90.7
# Episode =  327, score = 13866.121 (best = 13866.121) position = -23.5 -23.9 90.4
# Episode =  328, score = 13925.042 (best = 13925.042) position = -23.1 -3.2 90.1
# Episode =  329, score = 13972.563 (best = 13972.563) position = -22.2 23.1 88.0
# Episode =  330, score = 14012.707 (best = 14012.707) position = -23.7 -29.4 90.1
# Episode =  331, score = 14072.759 (best = 14072.759) position = -23.0 -9.6 90.7
# Episode =  332, score = 14126.716 (best = 14126.716) position = -22.2 17.0 88.8
# Episode =  333, score = 14170.685 (best = 14170.685) position = -23.9 -23.5 90.8
# Episode =  334, score = 14226.432 (best = 14226.432) position = -23.1 -19.3 90.4
# Episode =  335, score = 14240.756 (best = 14240.756) position = -24.3 -44.5 89.0
# Episode =  336, score = 14277.273 (best = 14277.273) position = -24.0 -29.8 90.5
# Episode =  337, score = 14337.954 (best = 14337.954) position = -23.1 -3.2 90.6
# Episode =  338, score = 14360.559 (best = 14360.559) position = -24.2 -41.1 89.3
# Episode =  339, score = 14415.891 (best = 14415.891) position = -23.4 -16.0 90.7
# Episode =  340, score = 14465.265 (best = 14465.265) position = -23.6 -21.2 90.6
# Episode =  341, score = 14519.382 (best = 14519.382) position = -23.5 -19.0 90.6
# Episode =  342, score = 14579.041 (best = 14579.041) position = -22.5 10.3 89.7
# Episode =  343, score = 14639.083 (best = 14639.083) position = -23.0 -0.5 90.2
# Episode =  344, score = 14697.286 (best = 14697.286) position = -23.2 -11.3 90.2
# Episode =  345, score = 14753.585 (best = 14753.585) position = -23.2 -15.7 90.4
# Episode =  346, score = 14734.913 (best = 14753.585) position = -24.8 -57.3 87.5
# Episode =  347, score = 14795.156 (best = 14795.156) position = -23.2 -9.0 90.5
# Episode =  348, score = 14812.595 (best = 14812.595) position = -24.1 -45.6 88.7
# Episode =  349, score = 14859.707 (best = 14859.707) position = -23.7 -26.2 90.2
# Episode =  350, score = 14915.575 (best = 14915.575) position = -23.2 -13.2 90.5
# Episode =  351, score = 14975.294 (best = 14975.294) position = -22.7 4.4 89.9
# Episode =  352, score = 15036.241 (best = 15036.241) position = -22.9 -6.9 90.5
# Episode =  353, score = 15091.016 (best = 15091.016) position = -23.3 -15.8 90.5
# Episode =  354, score = 15149.577 (best = 15149.577) position = -22.3 5.9 89.5
# Episode =  355, score = 15211.773 (best = 15211.773) position = -22.9 -4.7 90.6
# Episode =  356, score = 15258.563 (best = 15258.563) position = -23.6 -26.3 90.5
# Episode =  357, score = 15316.390 (best = 15316.390) position = -22.4 10.0 89.5
# Episode =  358, score = 15370.069 (best = 15370.069) position = -22.4 15.7 88.8
# Episode =  359, score = 15426.866 (best = 15426.866) position = -23.4 -13.6 90.6
# Episode =  360, score = 15450.087 (best = 15450.087) position = -24.4 -37.7 89.7
# Episode =  361, score = 15444.644 (best = 15450.087) position = -24.9 -52.1 88.6
# Episode =  362, score = 15504.123 (best = 15504.123) position = -23.0 -9.4 90.4
# Episode =  363, score = 15565.935 (best = 15565.935) position = -22.5 -2.7 90.3
# Episode =  364, score = 15620.070 (best = 15620.070) position = -22.2 16.3 88.9
# Episode =  365, score = 15636.701 (best = 15636.701) position = -24.2 -45.6 88.8
# Episode =  366, score = 15651.596 (best = 15651.596) position = -24.5 -41.4 89.8
# Episode =  367, score = 15712.149 (best = 15712.149) position = -23.3 -3.2 90.6
# Episode =  368, score = 15774.102 (best = 15774.102) position = -23.0 -1.0 90.5
# Episode =  369, score = 15808.445 (best = 15808.445) position = -24.1 -32.6 90.2
# Episode =  370, score = 15855.435 (best = 15855.435) position = -23.6 -26.1 90.1
# Episode =  371, score = 15915.460 (best = 15915.460) position = -23.1 -5.5 90.6
# Episode =  372, score = 15974.692 (best = 15974.692) position = -22.4 4.9 89.6
# Episode =  373, score = 15894.651 (best = 15974.692) position = -9.5 1.5 0.0
# Episode =  374, score = 15886.320 (best = 15974.692) position = -1.3 1.0 0.0
# Episode =  375, score = 15860.899 (best = 15974.692) position = -1.1 -0.3 0.0
# Episode =  376, score = 15825.731 (best = 15974.692) position = -0.6 -0.4 0.0
# Episode =  377, score = 15807.698 (best = 15974.692) position = -0.9 0.1 0.0
# Episode =  378, score = 15796.829 (best = 15974.692) position = -1.6 -0.0 0.0
# Episode =  379, score = 15761.478 (best = 15974.692) position = -1.7 -0.0 0.0
# Episode =  380, score = 15743.341 (best = 15974.692) position = -1.6 -0.2 0.0
# Episode =  381, score = 15713.383 (best = 15974.692) position = -1.7 -0.1 0.0
# Episode =  382, score = 15685.383 (best = 15974.692) position = -1.6 -0.4 0.0
# Episode =  383, score = 15667.152 (best = 15974.692) position = -1.8 -0.3 0.0
# Episode =  384, score = 15637.251 (best = 15974.692) position = -1.9 4.6 0.0
# Episode =  385, score = 15621.605 (best = 15974.692) position = -1.0 -0.4 0.0
# Episode =  386, score = 15597.217 (best = 15974.692) position = -0.7 -0.2 0.0
# Episode =  387, score = 15588.949 (best = 15974.692) position = -2.0 0.0 0.0
# Episode =  388, score = 15560.917 (best = 15974.692) position = -2.3 0.3 0.0
# Episode =  389, score = 15535.670 (best = 15974.692) position = -1.1 0.2 0.0
# Episode =  390, score = 15522.260 (best = 15974.692) position = -0.9 2.0 0.0
# Episode =  391, score = 15509.354 (best = 15974.692) position = -1.7 -1.2 0.0
# Episode =  392, score = 15489.370 (best = 15974.692) position = -0.8 -1.0 0.0
# Episode =  393, score = 15466.272 (best = 15974.692) position = -1.6 -3.7 0.0
# Episode =  394, score = 15436.326 (best = 15974.692) position = -1.8 -0.4 0.0
# Episode =  395, score = 15423.218 (best = 15974.692) position = 2.2 0.3 0.0
# Episode =  396, score = 15400.411 (best = 15974.692) position = -4.6 -0.2 0.0
# Episode =  397, score = 15388.393 (best = 15974.692) position = -7.9 -1.3 0.0
# Episode =  398, score = 15360.093 (best = 15974.692) position = 0.9 2.9 0.0
# Episode =  399, score = 15346.458 (best = 15974.692) position = 17.7 -2.7 0.0
# Episode =  400, score = 15326.544 (best = 15974.692) position = 4.9 -4.3 0.0
# Episode =  401, score = 15315.664 (best = 15974.692) position = -1.8 2.3 0.0
# Episode =  402, score = 15298.139 (best = 15974.692) position = 0.6 -6.7 0.0
# Episode =  403, score = 15267.791 (best = 15974.692) position = -4.6 0.2 0.0
# Episode =  404, score = 15249.673 (best = 15974.692) position = -3.3 3.0 0.0
# Episode =  405, score = 15227.895 (best = 15974.692) position = 0.4 7.6 0.0
# Episode =  406, score = 15199.934 (best = 15974.692) position = -0.2 4.1 0.0
# Episode =  407, score = 15150.651 (best = 15974.692) position = 0.5 8.6 0.0
# Episode =  408, score = 15146.156 (best = 15974.692) position = -1.3 -3.1 0.0
# Episode =  409, score = 15144.057 (best = 15974.692) position = -1.4 -1.9 0.0
# Episode =  410, score = 15125.278 (best = 15974.692) position = 1.4 7.7 0.0
# Episode =  411, score = 15093.926 (best = 15974.692) position = 1.1 -2.7 0.0
# Episode =  412, score = 15073.959 (best = 15974.692) position = -1.8 0.4 0.0
# Episode =  413, score = 15052.340 (best = 15974.692) position = -1.8 1.6 0.0
# Episode =  414, score = 15043.619 (best = 15974.692) position = -1.1 1.7 0.0
# Episode =  415, score = 15031.291 (best = 15974.692) position = -0.0 0.7 0.0
# Episode =  416, score = 14645.351 (best = 15974.692) position = -12.1 110.6 0.0
# Episode =  417, score = 14640.872 (best = 15974.692) position = -0.5 15.8 0.0
# Episode =  418, score = 14619.995 (best = 15974.692) position = -2.2 1.3 0.0
# Episode =  419, score = 14599.957 (best = 15974.692) position = -1.7 0.3 0.0
# Episode =  420, score = 14581.321 (best = 15974.692) position = -2.0 0.2 0.0
# Episode =  421, score = 14572.457 (best = 15974.692) position = -1.1 2.8 0.0
# Episode =  422, score = 14569.806 (best = 15974.692) position = 0.6 -0.8 0.0
# Episode =  423, score = 14563.588 (best = 15974.692) position = -1.4 -1.9 0.0
# Episode =  424, score = 14562.239 (best = 15974.692) position = -0.3 -1.3 0.0
# Episode =  425, score = 14541.384 (best = 15974.692) position = -2.6 0.6 0.0
# Episode =  426, score = 14521.181 (best = 15974.692) position = -2.9 -1.9 0.0
# Episode =  427, score = 14509.416 (best = 15974.692) position = 0.9 -0.2 0.0
# Episode =  428, score = 14500.127 (best = 15974.692) position = -0.1 -1.5 0.0
# Episode =  429, score = 14482.378 (best = 15974.692) position = -2.9 -2.6 0.0
# Episode =  430, score = 14454.523 (best = 15974.692) position = 1.7 10.5 0.0
# Episode =  431, score = 14429.137 (best = 15974.692) position = -1.2 -1.2 0.0
# Episode =  432, score = 14398.790 (best = 15974.692) position = 0.5 1.3 0.0
# Episode =  433, score = 14377.085 (best = 15974.692) position = -0.2 0.3 0.0
# Episode =  434, score = 14364.995 (best = 15974.692) position = -0.9 1.0 0.0
# Episode =  435, score = 14341.709 (best = 15974.692) position = -1.8 -2.0 0.0
# Episode =  436, score = 14306.353 (best = 15974.692) position = -1.6 -4.5 0.0
# Episode =  437, score = 14288.097 (best = 15974.692) position = -1.0 -1.3 0.0
# Episode =  438, score = 14247.148 (best = 15974.692) position = -2.9 4.0 0.0
# Episode =  439, score = 14245.715 (best = 15974.692) position = 1.5 -0.8 0.0
# Episode =  440, score = 14239.489 (best = 15974.692) position = 1.9 0.4 0.0
# Episode =  441, score = 14225.639 (best = 15974.692) position = 0.6 -1.6 0.0
# Episode =  442, score = 14217.466 (best = 15974.692) position = 2.5 -0.3 0.0
# Episode =  443, score = 14198.606 (best = 15974.692) position = 2.3 1.7 0.0
# Episode =  444, score = 14196.394 (best = 15974.692) position = 0.2 2.3 0.0
# Episode =  445, score = 14166.881 (best = 15974.692) position = 0.2 -0.8 0.0
# Episode =  446, score = 14137.775 (best = 15974.692) position = -0.1 -0.7 0.0
# Episode =  447, score = 14127.215 (best = 15974.692) position = 1.6 1.1 0.0
# Episode =  448, score = 14122.693 (best = 15974.692) position = -1.8 1.2 0.0
# Episode =  449, score = 14116.515 (best = 15974.692) position = -0.6 1.5 0.0
# Episode =  450, score = 14093.099 (best = 15974.692) position = -2.4 6.2 0.0
# Episode =  451, score = 14076.212 (best = 15974.692) position = 0.3 -0.3 0.0
# Episode =  452, score = 14065.396 (best = 15974.692) position = 0.4 -1.4 0.0
# Episode =  453, score = 14028.931 (best = 15974.692) position = 0.6 9.5 0.0
# Episode =  454, score = 14013.694 (best = 15974.692) position = -2.3 -1.6 0.0
# Episode =  455, score = 13999.255 (best = 15974.692) position = -2.3 2.8 0.0
# Episode =  456, score = 13989.106 (best = 15974.692) position = -1.3 -1.6 0.0
# Episode =  457, score = 13969.735 (best = 15974.692) position = -1.5 -0.4 0.0
# Episode =  458, score = 13953.772 (best = 15974.692) position = -3.4 -1.5 0.0
# Episode =  459, score = 13952.089 (best = 15974.692) position = -2.5 -4.7 0.0
# Episode =  460, score = 13945.994 (best = 15974.692) position = -3.2 1.0 0.0
# Episode =  461, score = 13927.503 (best = 15974.692) position = -0.2 4.1 0.0
# Episode =  462, score = 13919.929 (best = 15974.692) position = 2.1 2.4 0.0
# Episode =  463, score = 13904.126 (best = 15974.692) position = -0.3 2.1 0.0
# Episode =  464, score = 13879.128 (best = 15974.692) position = 0.9 -1.0 0.0
# Episode =  465, score = 13867.579 (best = 15974.692) position = 0.4 2.5 0.0
# Episode =  466, score = 13857.653 (best = 15974.692) position = -1.6 0.4 0.0
# Episode =  467, score = 13843.506 (best = 15974.692) position = 6.6 0.2 0.0
# Episode =  468, score = 13832.180 (best = 15974.692) position = 3.5 -1.5 0.0
# Episode =  469, score = 13821.953 (best = 15974.692) position = -10.2 2.4 0.0
# Episode =  470, score = 13817.243 (best = 15974.692) position = -7.5 -2.9 0.0
# Episode =  471, score = 13806.416 (best = 15974.692) position = -1.9 5.9 0.0
# Episode =  472, score = 13781.098 (best = 15974.692) position = -3.2 3.5 0.0
# Episode =  473, score = 13767.249 (best = 15974.692) position = 0.0 0.4 0.0
# Episode =  474, score = 13760.255 (best = 15974.692) position = 2.7 -2.2 0.0
# Episode =  475, score = 13734.310 (best = 15974.692) position = 2.4 -0.0 0.0
# Episode =  476, score = 13700.039 (best = 15974.692) position = 9.5 -4.6 0.0
# Episode =  477, score = 13682.019 (best = 15974.692) position = -1.5 3.3 0.0
# Episode =  478, score = 13656.949 (best = 15974.692) position = -0.9 0.3 0.0
# Episode =  479, score = 13643.248 (best = 15974.692) position = -1.3 2.7 0.0
# Episode =  480, score = 13629.587 (best = 15974.692) position = -1.1 0.7 0.0
# Episode =  481, score = 13587.421 (best = 15974.692) position = -0.2 2.3 0.0
# Episode =  482, score = 13578.209 (best = 15974.692) position = 0.9 -0.8 0.0
# Episode =  483, score = 13550.800 (best = 15974.692) position = -5.0 -1.6 0.0
# Episode =  484, score = 13532.655 (best = 15974.692) position = 0.0 2.0 0.0
# Episode =  485, score = 13514.632 (best = 15974.692) position = 0.0 2.0 0.0
# Episode =  486, score = 13465.035 (best = 15974.692) position = 0.0 -0.0 0.0
# Episode =  487, score = 13456.308 (best = 15974.692) position = 0.0 0.7 0.0
# Episode =  488, score = 13449.735 (best = 15974.692) position = 0.0 -2.7 0.0
# Episode =  489, score = 13433.042 (best = 15974.692) position = 0.0 1.0 0.0
# Episode =  490, score = 13400.694 (best = 15974.692) position = 0.0 -2.0 0.0
# Episode =  491, score = 13389.023 (best = 15974.692) position = 0.0 0.1 0.0
# Episode =  492, score = 13365.073 (best = 15974.692) position = 0.0 -2.1 0.0
# Episode =  493, score = 13356.722 (best = 15974.692) position = 0.0 1.9 0.0
# Episode =  494, score = 13338.346 (best = 15974.692) position = 0.0 2.4 0.0
# Episode =  495, score = 13318.196 (best = 15974.692) position = 0.0 1.3 0.0
# Episode =  496, score = 13291.995 (best = 15974.692) position = 0.0 1.3 0.0
# Episode =  497, score = 13273.768 (best = 15974.692) position = 0.0 1.9 0.0
# Episode =  498, score = 13242.239 (best = 15974.692) position = 0.0 0.8 0.0
# Episode =  499, score = 13230.616 (best = 15974.692) position = 0.0 0.3 0.0
# Episode =  500, score = 13179.049 (best = 15974.692) position = 0.0 -3.3 0.0
# Episode =  501, score = 13169.944 (best = 15974.692) position = -0.2 2.3 0.0
# Episode =  502, score = 13158.004 (best = 15974.692) position = -2.1 0.3 0.0
# Episode =  503, score = 13145.277 (best = 15974.692) position = 3.2 5.4 0.0
# Episode =  504, score = 13115.707 (best = 15974.692) position = 1.2 0.2 0.0
# Episode =  505, score = 13102.371 (best = 15974.692) position = -0.7 1.2 0.0
# Episode =  506, score = 13081.443 (best = 15974.692) position = -1.1 -1.9 0.0
# Episode =  507, score = 13077.809 (best = 15974.692) position = -1.0 0.4 0.0
# Episode =  508, score = 13062.273 (best = 15974.692) position = -2.1 -1.4 0.0
# Episode =  509, score = 13049.467 (best = 15974.692) position = 0.6 0.4 0.0
# Episode =  510, score = 13036.012 (best = 15974.692) position = -1.2 6.3 0.0
# Episode =  511, score = 13021.110 (best = 15974.692) position = 0.2 1.3 0.0
# Episode =  512, score = 13013.964 (best = 15974.692) position = -2.8 0.4 0.0
# Episode =  513, score = 12996.283 (best = 15974.692) position = -1.5 -2.9 0.0
# Episode =  514, score = 12968.346 (best = 15974.692) position = -1.2 -4.2 0.0
# Episode =  515, score = 12961.953 (best = 15974.692) position = -0.9 3.6 0.0
# Episode =  516, score = 12948.818 (best = 15974.692) position = -1.9 -1.1 0.0
# Episode =  517, score = 12932.394 (best = 15974.692) position = -0.9 5.9 0.0
# Episode =  518, score = 12922.560 (best = 15974.692) position = -1.2 0.1 0.0
# Episode =  519, score = 12897.333 (best = 15974.692) position = -3.2 -1.3 0.0
# Episode =  520, score = 12874.117 (best = 15974.692) position = 0.4 -0.5 0.0
# Episode =  521, score = 12826.553 (best = 15974.692) position = -5.4 0.6 0.0
# Episode =  522, score = 12808.367 (best = 15974.692) position = -0.8 -1.6 0.0
# Episode =  523, score = 12785.331 (best = 15974.692) position = -6.8 -3.0 0.0
# Episode =  524, score = 12740.449 (best = 15974.692) position = -1.4 -3.4 0.0
# Episode =  525, score = 12706.030 (best = 15974.692) position = -1.2 1.0 0.0
# Episode =  526, score = 12675.531 (best = 15974.692) position = -0.2 -0.2 0.0
# Episode =  527, score = 12649.489 (best = 15974.692) position = -1.9 1.7 0.0
# Episode =  528, score = 12620.243 (best = 15974.692) position = -1.6 0.6 0.0
# Episode =  529, score = 12604.659 (best = 15974.692) position = -1.3 1.9 0.0
# Episode =  530, score = 12586.742 (best = 15974.692) position = -2.1 1.5 0.0
# Episode =  531, score = 12561.339 (best = 15974.692) position = -1.6 1.0 0.0
# Episode =  532, score = 12537.004 (best = 15974.692) position = -0.9 1.8 0.0
# Episode =  533, score = 12530.999 (best = 15974.692) position = -1.3 -1.0 0.0
# Episode =  534, score = 12520.489 (best = 15974.692) position = -4.5 4.6 0.0
# Episode =  535, score = 12509.249 (best = 15974.692) position = -1.1 -0.3 0.0
# Episode =  536, score = 12497.796 (best = 15974.692) position = -2.1 -1.6 0.0
# Episode =  537, score = 12458.643 (best = 15974.692) position = -8.7 -1.6 0.0
# Episode =  538, score = 12428.495 (best = 15974.692) position = -6.0 -0.0 0.0
# Episode =  539, score = 12397.056 (best = 15974.692) position = -2.5 0.7 0.0
# Episode =  540, score = 12381.729 (best = 15974.692) position = -2.9 1.9 0.0
# Episode =  541, score = 12371.118 (best = 15974.692) position = -2.8 2.3 0.0
# Episode =  542, score = 12356.118 (best = 15974.692) position = -2.2 -0.0 0.0
# Episode =  543, score = 12292.152 (best = 15974.692) position = -7.9 3.2 0.0
# Episode =  544, score = 12278.253 (best = 15974.692) position = -0.9 -8.2 0.0
# Episode =  545, score = 12260.490 (best = 15974.692) position = -0.5 -1.7 0.0
# Episode =  546, score = 12254.976 (best = 15974.692) position = -0.7 -0.3 0.0
# Episode =  547, score = 12246.997 (best = 15974.692) position = -1.5 6.5 0.0
# Episode =  548, score = 12226.604 (best = 15974.692) position = -0.5 4.5 0.0
# Episode =  549, score = 12210.901 (best = 15974.692) position = -4.0 -1.8 0.0
# Episode =  550, score = 12185.400 (best = 15974.692) position = -2.8 0.8 0.0
# Episode =  551, score = 12173.122 (best = 15974.692) position = -2.3 2.2 0.0
# Episode =  552, score = 12145.551 (best = 15974.692) position = -1.7 1.4 0.0
# Episode =  553, score = 12115.975 (best = 15974.692) position = -1.1 2.8 0.0
# Episode =  554, score = 12105.708 (best = 15974.692) position = 0.2 3.6 0.0
# Episode =  555, score = 12090.060 (best = 15974.692) position = -1.5 1.9 0.0
# Episode =  556, score = 12060.871 (best = 15974.692) position = -1.4 1.4 0.0
# Episode =  557, score = 12035.127 (best = 15974.692) position = -3.0 3.7 0.0
# Episode =  558, score = 12008.640 (best = 15974.692) position = -5.7 -3.5 0.0
# Episode =  559, score = 12002.894 (best = 15974.692) position = -1.6 -0.2 0.0
# Episode =  560, score = 11986.102 (best = 15974.692) position = -0.8 2.1 0.0
# Episode =  561, score = 11962.958 (best = 15974.692) position = -0.6 2.5 0.0
# Episode =  562, score = 11935.543 (best = 15974.692) position = -1.0 -1.2 0.0
# Episode =  563, score = 11922.446 (best = 15974.692) position = -1.1 1.1 0.0
# Episode =  564, score = 11911.769 (best = 15974.692) position = -2.1 1.4 0.0
# Episode =  565, score = 11887.747 (best = 15974.692) position = -3.9 -1.2 0.0
# Episode =  566, score = 11867.316 (best = 15974.692) position = 0.1 0.9 0.0
# Episode =  567, score = 11841.558 (best = 15974.692) position = 0.2 5.4 0.0
# Episode =  568, score = 11826.941 (best = 15974.692) position = 2.7 7.6 0.0
# Episode =  569, score = 11786.219 (best = 15974.692) position = -3.9 -2.4 0.0
# Episode =  570, score = 11735.056 (best = 15974.692) position = 1.7 -0.2 0.0
# Episode =  571, score = 11717.163 (best = 15974.692) position = -4.5 0.1 0.0
# Episode =  572, score = 11677.816 (best = 15974.692) position = 6.6 -0.4 0.0
# Episode =  573, score = 11642.017 (best = 15974.692) position = -1.3 1.3 0.0
# Episode =  574, score = 11628.814 (best = 15974.692) position = -5.2 -0.3 0.0
# Episode =  575, score = 11607.171 (best = 15974.692) position = 3.1 -0.2 0.0
# Episode =  576, score = 11574.927 (best = 15974.692) position = -5.5 -0.8 0.0
# Episode =  577, score = 11563.280 (best = 15974.692) position = -8.7 0.3 0.0
# Episode =  578, score = 11536.243 (best = 15974.692) position = -3.0 1.7 0.0
# Episode =  579, score = 11517.275 (best = 15974.692) position = -9.0 -0.9 0.0
# Episode =  580, score = 11470.915 (best = 15974.692) position = -3.7 0.1 0.0
# Episode =  581, score = 11452.650 (best = 15974.692) position = 6.4 -0.6 0.0
# Episode =  582, score = 11429.723 (best = 15974.692) position = -0.8 -0.1 0.0
# Episode =  583, score = 11411.794 (best = 15974.692) position = -0.2 2.2 0.0
# Episode =  584, score = 11382.622 (best = 15974.692) position = -4.1 3.9 0.0
# Episode =  585, score = 11365.730 (best = 15974.692) position = -1.7 2.4 0.0
# Episode =  586, score = 11347.088 (best = 15974.692) position = -5.7 3.7 0.0
# Episode =  587, score = 11311.972 (best = 15974.692) position = -1.5 1.6 0.0
# Episode =  588, score = 11287.393 (best = 15974.692) position = 3.3 -0.9 0.0
# Episode =  589, score = 11264.864 (best = 15974.692) position = -2.2 0.4 0.0
# Episode =  590, score = 11259.996 (best = 15974.692) position = -3.0 0.2 0.0
# Episode =  591, score = 11224.394 (best = 15974.692) position = -12.5 1.0 0.0
# Episode =  592, score = 11216.798 (best = 15974.692) position = -2.3 -0.2 0.0
# Episode =  593, score = 11184.116 (best = 15974.692) position = -3.3 -0.1 0.0
# Episode =  594, score = 11174.454 (best = 15974.692) position = -1.6 0.7 0.0
# Episode =  595, score = 11155.707 (best = 15974.692) position = -2.1 0.1 0.0
# Episode =  596, score = 11134.238 (best = 15974.692) position = -2.5 2.5 0.0
# Episode =  597, score = 11132.198 (best = 15974.692) position = 0.8 -2.2 0.0
# Episode =  598, score = 11091.165 (best = 15974.692) position = -1.5 -0.1 0.0
# Episode =  599, score = 11059.667 (best = 15974.692) position = -0.4 -2.1 0.0
# Episode =  600, score = 11030.334 (best = 15974.692) position = -5.7 0.4 0.0
# Episode =  601, score = 11019.699 (best = 15974.692) position = -7.9 -0.4 0.0
# Episode =  602, score = 10987.073 (best = 15974.692) position = -1.2 1.9 0.0
# Episode =  603, score = 10973.011 (best = 15974.692) position = -2.7 1.6 0.0
# Episode =  604, score = 10944.927 (best = 15974.692) position = -2.3 0.1 0.0
# Episode =  605, score = 10930.418 (best = 15974.692) position = 0.9 0.8 0.0
# Episode =  606, score = 10922.876 (best = 15974.692) position = -2.3 1.2 0.0
# Episode =  607, score = 10909.112 (best = 15974.692) position = -5.6 9.8 0.0
# Episode =  608, score = 10896.555 (best = 15974.692) position = -1.9 0.2 0.0
# Episode =  609, score = 10857.844 (best = 15974.692) position = -0.9 -1.6 0.0
# Episode =  610, score = 10817.422 (best = 15974.692) position = -1.9 4.6 0.0
# Episode =  611, score = 10805.568 (best = 15974.692) position = -2.3 8.6 0.0
# Episode =  612, score = 10795.157 (best = 15974.692) position = -3.7 -0.1 0.0
# Episode =  613, score = 10781.815 (best = 15974.692) position = -1.5 -0.3 0.0
# Episode =  614, score = 10753.962 (best = 15974.692) position = -1.4 2.6 0.0
# Episode =  615, score = 10725.258 (best = 15974.692) position = -4.2 -0.3 0.0
# Episode =  616, score = 10707.834 (best = 15974.692) position = -1.6 9.7 0.0
# Episode =  617, score = 10689.065 (best = 15974.692) position = -2.5 0.7 0.0
# Episode =  618, score = 10669.310 (best = 15974.692) position = -2.1 0.9 0.0
# Episode =  619, score = 10632.919 (best = 15974.692) position = -3.0 2.5 0.0
# Episode =  620, score = 10615.299 (best = 15974.692) position = -2.5 -0.1 0.0
# Episode =  621, score = 10578.304 (best = 15974.692) position = -6.1 1.1 0.0
# Episode =  622, score = 10546.642 (best = 15974.692) position = -3.2 -0.1 0.0
# Episode =  623, score = 10518.668 (best = 15974.692) position = -4.1 0.5 0.0
# Episode =  624, score = 10481.600 (best = 15974.692) position = -8.8 -2.1 0.0
# ...
# Episode =  630, score = 10295.225 (best = 15974.692) position = -1.4 -0.3 0.0
# Episode =  631, score = 10278.223 (best = 15974.692) position = -1.9 1.3 0.0
# Episode =  632, score = 10260.389 (best = 15974.692) position = -2.4 6.2 0.0
# Episode =  633, score = 10250.915 (best = 15974.692) position = -4.0 -0.0 0.0
# Episode =  634, score = 10234.041 (best = 15974.692) position = -0.5 -0.0 0.0
# Episode =  635, score = 10209.587 (best = 15974.692) position = -3.5 0.3 0.0
# Episode =  636, score = 10173.774 (best = 15974.692) position = -1.9 1.4 0.0
# Episode =  637, score = 10143.429 (best = 15974.692) position = -4.4 -0.8 0.0
# Episode =  638, score = 10127.758 (best = 15974.692) position = -0.3 -0.1 0.0
# Episode =  639, score = 10100.124 (best = 15974.692) position = -7.0 15.6 0.0
# Episode =  640, score = 10070.610 (best = 15974.692) position = -0.2 0.0 0.0
# Episode =  641, score = 10039.393 (best = 15974.692) position = -4.4 1.1 0.0
# Episode =  642, score = 10016.491 (best = 15974.692) position = 4.3 -0.7 0.0
# Episode =  643, score = 9995.067 (best = 15974.692) position = -1.3 0.7 0.0
# Episode =  644, score = 9974.827 (best = 15974.692) position = 1.2 -4.6 0.0
# Episode =  645, score = 9953.174 (best = 15974.692) position = -7.0 0.6 0.0
# Episode =  646, score = 9932.361 (best = 15974.692) position = -0.9 0.4 0.0
# Episode =  647, score = 9922.250 (best = 15974.692) position = -6.7 1.2 0.0
# Episode =  648, score = 9893.072 (best = 15974.692) position = -2.7 7.2 0.0
# Episode =  649, score = 9866.691 (best = 15974.692) position = -4.1 4.7 0.0
# Episode =  650, score = 9847.004 (best = 15974.692) position = -9.0 0.7 0.0
# Episode =  651, score = 9820.254 (best = 15974.692) position = -3.9 9.9 0.0
# Episode =  652, score = 9812.924 (best = 15974.692) position = -6.7 5.3 0.0
# Episode =  653, score = 9779.726 (best = 15974.692) position = -3.5 9.4 0.0
# Episode =  654, score = 9753.572 (best = 15974.692) position = -2.6 0.5 0.0
# Episode =  655, score = 9719.582 (best = 15974.692) position = -4.6 2.0 0.0
# Episode =  656, score = 9698.114 (best = 15974.692) position = 1.8 -3.6 0.0
# Episode =  657, score = 9650.534 (best = 15974.692) position = -6.8 -1.4 0.0
# Episode =  658, score = 9632.345 (best = 15974.692) position = -5.9 14.9 0.0
# Episode =  659, score = 9611.198 (best = 15974.692) position = -0.8 -2.3 0.0
# Episode =  660, score = 9580.053 (best = 15974.692) position = -5.2 -1.1 0.0
# Episode =  661, score = 9564.839 (best = 15974.692) position = 1.3 -2.3 0.0
# Episode =  662, score = 9532.968 (best = 15974.692) position = 5.2 -2.9 0.0
# Episode =  663, score = 9508.597 (best = 15974.692) position = -8.6 3.4 0.0
# Episode =  664, score = 9475.675 (best = 15974.692) position = -5.6 -1.9 0.0
# Episode =  665, score = 9441.984 (best = 15974.692) position = -6.2 2.4 0.0
# Episode =  666, score = 9430.652 (best = 15974.692) position = -5.5 1.2 0.0
# Episode =  667, score = 9414.491 (best = 15974.692) position = -5.0 -0.8 0.0
# Episode =  668, score = 9389.300 (best = 15974.692) position = -7.6 2.5 0.0
# Episode =  669, score = 9381.673 (best = 15974.692) position = 1.4 -1.1 0.0
# Episode =  670, score = 9345.772 (best = 15974.692) position = -4.8 -0.1 0.0
# Episode =  671, score = 9314.718 (best = 15974.692) position = -5.1 -0.3 0.0
# Episode =  672, score = 9303.228 (best = 15974.692) position = -5.8 4.7 0.0
# Episode =  673, score = 9274.291 (best = 15974.692) position = -5.5 1.5 0.0
# Episode =  674, score = 9247.489 (best = 15974.692) position = -6.3 3.8 0.0
# Episode =  675, score = 9218.615 (best = 15974.692) position = -4.4 6.6 0.0
# Episode =  676, score = 9187.561 (best = 15974.692) position = -5.1 -0.5 0.0
# Episode =  677, score = 9160.432 (best = 15974.692) position = -3.8 9.2 0.0
# Episode =  678, score = 9131.720 (best = 15974.692) position = -6.2 21.7 0.0
# Episode =  679, score = 9116.934 (best = 15974.692) position = -3.6 7.4 0.0
# Episode =  680, score = 9097.569 (best = 15974.692) position = -5.7 2.1 0.0
# Episode =  681, score = 9066.184 (best = 15974.692) position = -8.5 -0.4 0.0
# Episode =  682, score = 9048.781 (best = 15974.692) position = -4.6 0.5 0.0
# Episode =  683, score = 9044.995 (best = 15974.692) position = -8.2 4.7 0.0
# Episode =  684, score = 9031.625 (best = 15974.692) position = -8.4 28.3 0.0
# Episode =  685, score = 9014.576 (best = 15974.692) position = -7.2 4.2 0.0
# Episode =  686, score = 9000.418 (best = 15974.692) position = -5.8 1.1 0.0
# Episode =  687, score = 8994.043 (best = 15974.692) position = -2.9 7.2 0.0
# Episode =  688, score = 8953.441 (best = 15974.692) position = -8.1 3.2 0.0
# Episode =  689, score = 8936.643 (best = 15974.692) position = -2.7 0.0 0.0
# Episode =  690, score = 8914.374 (best = 15974.692) position = -7.0 4.5 0.0
# Episode =  691, score = 8895.963 (best = 15974.692) position = -3.1 4.6 0.0
# Episode =  692, score = 8882.347 (best = 15974.692) position = -5.7 0.7 0.0
# Episode =  693, score = 8845.295 (best = 15974.692) position = -8.6 5.8 0.0
# Episode =  694, score = 8820.656 (best = 15974.692) position = -7.1 1.6 0.0
# Episode =  695, score = 8799.252 (best = 15974.692) position = -7.5 3.1 0.0
# Episode =  696, score = 8769.765 (best = 15974.692) position = -7.2 4.3 0.0
# Episode =  697, score = 8740.116 (best = 15974.692) position = -7.4 3.2 0.0
# Episode =  698, score = 8706.799 (best = 15974.692) position = -4.4 3.8 0.0
# Episode =  699, score = 8666.953 (best = 15974.692) position = -5.6 2.8 0.0
# Episode =  700, score = 8619.522 (best = 15974.692) position = -4.9 1.3 0.0
# Episode =  701, score = 8604.363 (best = 15974.692) position = -2.0 -0.8 0.0
# Episode =  702, score = 8588.357 (best = 15974.692) position = -5.4 -0.7 0.0
# Episode =  703, score = 8557.353 (best = 15974.692) position = -5.1 0.0 0.0
# Episode =  704, score = 8548.150 (best = 15974.692) position = 0.8 1.8 0.0
# Episode =  705, score = 8524.001 (best = 15974.692) position = -2.1 1.6 0.0
# Episode =  706, score = 8479.881 (best = 15974.692) position = -6.0 19.4 0.0
# Episode =  707, score = 8443.352 (best = 15974.692) position = -2.7 -1.0 0.0
# Episode =  708, score = 8431.278 (best = 15974.692) position = 0.9 1.4 0.0
# Episode =  709, score = 8361.807 (best = 15974.692) position = -5.8 28.2 0.0
# Episode =  710, score = 8330.756 (best = 15974.692) position = -5.2 -0.3 0.0
# Episode =  711, score = 8299.703 (best = 15974.692) position = -5.2 -0.2 0.0
# Episode =  712, score = 8203.424 (best = 15974.692) position = -3.2 9.8 0.0
# Episode =  713, score = 8182.407 (best = 15974.692) position = -1.2 0.5 0.0
# Episode =  714, score = 8151.366 (best = 15974.692) position = -5.2 0.0 0.0
# Episode =  715, score = 8118.277 (best = 15974.692) position = -4.6 2.4 0.0
# Episode =  716, score = 8082.408 (best = 15974.692) position = -3.2 0.1 0.0
# Episode =  717, score = 8037.660 (best = 15974.692) position = -4.3 0.8 0.0
# Episode =  718, score = 8025.049 (best = 15974.692) position = -1.2 -0.4 0.0
# Episode =  719, score = 7960.327 (best = 15974.692) position = -1.5 15.4 0.0
# Episode =  720, score = 7940.402 (best = 15974.692) position = -3.1 2.0 0.0
# Episode =  721, score = 7909.377 (best = 15974.692) position = -5.1 -0.2 0.0
# Episode =  722, score = 7898.653 (best = 15974.692) position = -1.4 2.5 0.0
# Episode =  723, score = 7862.289 (best = 15974.692) position = -4.8 2.2 0.0
# Episode =  724, score = 7840.415 (best = 15974.692) position = 0.5 -0.7 0.0
# Episode =  725, score = 7791.164 (best = 15974.692) position = -11.1 -0.4 0.0
# Episode =  726, score = 7767.063 (best = 15974.692) position = 0.3 0.1 0.0
# Episode =  727, score = 7751.195 (best = 15974.692) position = -11.7 0.8 0.0
# Episode =  728, score = 7730.881 (best = 15974.692) position = -7.3 -3.0 0.0
# Episode =  729, score = 7703.978 (best = 15974.692) position = -4.6 0.1 0.0
# Episode =  730, score = 7665.421 (best = 15974.692) position = -0.8 -0.2 0.0
# Episode =  731, score = 7653.230 (best = 15974.692) position = -2.1 1.1 0.0
# Episode =  732, score = 7643.607 (best = 15974.692) position = 0.3 -1.3 0.0
# Episode =  733, score = 7630.813 (best = 15974.692) position = -5.9 9.6 0.0
# Episode =  734, score = 7625.770 (best = 15974.692) position = -2.0 -1.1 0.0
# Episode =  735, score = 7587.803 (best = 15974.692) position = -12.5 -2.0 0.0
# Episode =  736, score = 7576.573 (best = 15974.692) position = 1.1 5.3 0.0
# Episode =  737, score = 7552.777 (best = 15974.692) position = 1.2 5.9 0.0
# Episode =  738, score = 7527.784 (best = 15974.692) position = -3.5 2.3 0.0
# Episode =  739, score = 7487.577 (best = 15974.692) position = 3.2 5.1 0.0
# Episode =  740, score = 7478.417 (best = 15974.692) position = 1.0 2.7 0.0
# Episode =  741, score = 7461.151 (best = 15974.692) position = -3.9 -5.7 0.0
# Episode =  742, score = 7440.293 (best = 15974.692) position = -10.1 -1.6 0.0
# Episode =  743, score = 7411.997 (best = 15974.692) position = 1.3 0.5 0.0
# Episode =  744, score = 7382.546 (best = 15974.692) position = -13.3 -3.9 0.0
# Episode =  745, score = 7364.977 (best = 15974.692) position = -5.1 0.8 0.0
# Episode =  746, score = 7334.389 (best = 15974.692) position = 1.3 1.7 0.0
# Episode =  747, score = 7309.577 (best = 15974.692) position = -2.3 -5.6 0.0
# Episode =  748, score = 7273.216 (best = 15974.692) position = 2.6 2.0 0.0
# Episode =  749, score = 7267.685 (best = 15974.692) position = -1.4 -2.6 0.0
# Episode =  750, score = 7260.233 (best = 15974.692) position = -9.6 -1.7 0.0
# Episode =  751, score = 7243.465 (best = 15974.692) position = 2.7 -2.2 0.0
# Episode =  752, score = 7221.629 (best = 15974.692) position = -5.6 1.3 0.0
# Episode =  753, score = 7195.055 (best = 15974.692) position = -2.2 3.5 0.0
# Episode =  754, score = 7174.505 (best = 15974.692) position = 0.1 6.6 0.0
# Episode =  755, score = 7164.994 (best = 15974.692) position = -2.7 4.5 0.0
# Episode =  756, score = 7131.942 (best = 15974.692) position = -5.0 1.0 0.0
# Episode =  757, score = 7096.835 (best = 15974.692) position = -1.0 -2.0 0.0
# Episode =  758, score = 7082.247 (best = 15974.692) position = -2.7 -1.2 0.0
# Episode =  759, score = 7042.149 (best = 15974.692) position = -3.3 0.7 0.0
# Episode =  760, score = 7021.578 (best = 15974.692) position = 3.2 3.9 0.0
# Episode =  761, score = 7005.535 (best = 15974.692) position = -3.9 6.6 0.0
# Episode =  762, score = 6992.915 (best = 15974.692) position = -1.6 -2.2 0.0
# Episode =  763, score = 6963.993 (best = 15974.692) position = -5.2 2.3 0.0
# Episode =  764, score = 6946.159 (best = 15974.692) position = -1.7 5.1 0.0
# Episode =  765, score = 6927.262 (best = 15974.692) position = -1.1 2.9 0.0
# Episode =  766, score = 6913.124 (best = 15974.692) position = 0.9 4.3 0.0
# Episode =  767, score = 6882.401 (best = 15974.692) position = 0.9 1.7 0.0
# Episode =  768, score = 6860.958 (best = 15974.692) position = -4.4 2.0 0.0
# Episode =  769, score = 6834.480 (best = 15974.692) position = -3.4 3.8 0.0
# Episode =  770, score = 6817.843 (best = 15974.692) position = -3.8 -6.1 0.0
# Episode =  771, score = 6792.628 (best = 15974.692) position = -4.2 6.6 0.0
# Episode =  772, score = 6769.871 (best = 15974.692) position = -3.6 2.1 0.0
# Episode =  773, score = 6737.287 (best = 15974.692) position = -0.0 1.2 0.0
# Episode =  774, score = 6713.738 (best = 15974.692) position = -7.1 3.4 0.0
# Episode =  775, score = 6680.139 (best = 15974.692) position = -2.0 -2.8 0.0
# Episode =  776, score = 6643.123 (best = 15974.692) position = 7.7 2.4 0.0
# Episode =  777, score = 6627.686 (best = 15974.692) position = -3.7 -0.6 0.0
# Episode =  778, score = 6604.709 (best = 15974.692) position = -10.2 -0.4 0.0
# Episode =  779, score = 6585.828 (best = 15974.692) position = -1.6 0.7 0.0
# Episode =  780, score = 6562.812 (best = 15974.692) position = -8.4 4.6 0.0
# Episode =  781, score = 6517.760 (best = 15974.692) position = 7.0 3.7 0.0
# Episode =  782, score = 6488.420 (best = 15974.692) position = 2.2 1.7 0.0
# Episode =  783, score = 6448.131 (best = 15974.692) position = -2.0 5.4 0.0
# Episode =  784, score = 6416.736 (best = 15974.692) position = 1.4 9.6 0.0
# Episode =  785, score = 6384.642 (best = 15974.692) position = -7.7 1.3 0.0
# Episode =  786, score = 6370.438 (best = 15974.692) position = -2.1 4.1 0.0
# Episode =  787, score = 6364.590 (best = 15974.692) position = 3.9 -0.7 0.0
# Episode =  788, score = 6338.594 (best = 15974.692) position = -0.2 -3.9 0.0
# Episode =  789, score = 6314.371 (best = 15974.692) position = -1.4 8.2 0.0
# Episode =  790, score = 6270.022 (best = 15974.692) position = -0.8 -0.9 0.0
# Episode =  791, score = 6253.030 (best = 15974.692) position = 0.1 -3.1 0.0
# Episode =  792, score = 6224.361 (best = 15974.692) position = 2.7 -0.6 0.0
# Episode =  793, score = 6198.951 (best = 15974.692) position = -3.8 -1.8 0.0
# Episode =  794, score = 6180.781 (best = 15974.692) position = -3.8 5.6 0.0
# Episode =  795, score = 6157.126 (best = 15974.692) position = 0.3 6.0 0.0
# Episode =  796, score = 6145.640 (best = 15974.692) position = -6.9 0.7 0.0
# Episode =  797, score = 6081.099 (best = 15974.692) position = -13.9 5.0 0.0
# Episode =  798, score = 6046.709 (best = 15974.692) position = -10.1 -0.3 0.0
# Episode =  799, score = 6015.769 (best = 15974.692) position = -2.4 1.9 0.0
# Episode =  800, score = 5966.296 (best = 15974.692) position = 7.6 -5.3 0.0
# Episode =  801, score = 5945.061 (best = 15974.692) position = -8.3 -6.6 0.0
# Episode =  802, score = 5932.851 (best = 15974.692) position = -8.8 1.0 0.0
# Episode =  803, score = 5917.601 (best = 15974.692) position = -7.6 1.4 0.0
# Episode =  804, score = 5877.773 (best = 15974.692) position = 4.5 4.0 0.0
# Episode =  805, score = 5856.129 (best = 15974.692) position = -12.5 3.1 0.0
# Episode =  806, score = 5822.190 (best = 15974.692) position = -2.2 2.4 0.0
# Episode =  807, score = 5781.083 (best = 15974.692) position = -3.2 6.0 0.0
# Episode =  808, score = 5763.620 (best = 15974.692) position = -0.3 4.0 0.0
# Episode =  809, score = 5723.901 (best = 15974.692) position = -11.0 -1.3 0.0
# Episode =  810, score = 5695.153 (best = 15974.692) position = 0.8 -1.2 0.0
# Episode =  811, score = 5687.500 (best = 15974.692) position = -5.2 3.8 0.0
# Episode =  812, score = 5668.249 (best = 15974.692) position = -8.5 2.2 0.0
# Episode =  813, score = 5636.743 (best = 15974.692) position = -2.1 2.1 0.0
# Episode =  814, score = 5603.715 (best = 15974.692) position = 1.0 -10.0 0.0
# Episode =  815, score = 5585.524 (best = 15974.692) position = 7.4 -4.2 0.0
# Episode =  816, score = 5545.936 (best = 15974.692) position = -4.3 2.4 0.0
# Episode =  817, score = 5516.004 (best = 15974.692) position = -7.0 -3.9 0.0
# Episode =  818, score = 5474.084 (best = 15974.692) position = -2.4 0.1 0.0
# Episode =  819, score = 5444.469 (best = 15974.692) position = -0.6 3.5 0.0
# Episode =  820, score = 5415.247 (best = 15974.692) position = 0.8 0.4 0.0
# Episode =  821, score = 5397.667 (best = 15974.692) position = -2.3 -0.5 0.0
# Episode =  822, score = 5377.902 (best = 15974.692) position = -1.8 1.0 0.0
# Episode =  823, score = 5344.068 (best = 15974.692) position = -0.3 2.5 0.0
# Episode =  824, score = 5325.428 (best = 15974.692) position = -2.2 4.8 0.0
# Episode =  825, score = 5284.331 (best = 15974.692) position = -3.9 2.5 0.0
# Episode =  826, score = 5262.460 (best = 15974.692) position = -7.8 2.5 0.0
# Episode =  827, score = 5243.874 (best = 15974.692) position = -0.9 0.9 0.0
# Episode =  828, score = 5217.725 (best = 15974.692) position = -3.0 3.4 0.0
# Episode =  829, score = 5186.281 (best = 15974.692) position = -3.5 3.7 0.0
# Episode =  830, score = 5169.099 (best = 15974.692) position = -1.8 2.2 0.0
# Episode =  831, score = 5141.881 (best = 15974.692) position = -2.4 4.2 0.0
# Episode =  832, score = 5118.878 (best = 15974.692) position = -6.2 -1.6 0.0
# Episode =  833, score = 5093.003 (best = 15974.692) position = -4.8 2.7 0.0
# Episode =  834, score = 5071.856 (best = 15974.692) position = 2.4 -2.2 0.0
# Episode =  835, score = 5059.712 (best = 15974.692) position = -3.1 0.6 0.0
# Episode =  836, score = 5033.867 (best = 15974.692) position = -2.2 2.9 0.0
# Episode =  837, score = 5006.272 (best = 15974.692) position = -4.2 -7.1 0.0
# Episode =  838, score = 4963.473 (best = 15974.692) position = -8.3 2.8 0.0

# %%
target_pos

# %%
task.sim.pose

# %%
reward

# %% [markdown]
# ## Plot the Rewards
#
# Once you are satisfied with your performance, plot the episode rewards, either from a single run, or averaged over multiple runs.

# %%
## TODO: Plot the rewards.
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(results['Episode'], results['Score'], label='Reward')
#plt.plot(results['Episode'], rewards, label = 'Reward magnitude over episode')
#plt.plot(results['Episode'], results['Best Score'], label='Best total reward')
plt.xlabel('Episode number')
plt.ylabel('Accumulated Score')
plt.legend()

# %% [markdown]
# ## Reflections
#
# **Question 1**: Describe the task that you specified in `task.py`.  How did you design the reward function?
#
# **Answer**:
#
# I set a target location for the quadroter to be 100 units off the ground. As a result, I separated the reward function into three distinct phases:
#
# 1.) I defined an error function to be proportional to the magnitude of the error, otherwise known as the distance between the current position and the target position, in each cartesian coordinate, x, y, and z. From there, I multipled a scaling factor to this error term to prevent too large of an error being added over the course of the agent's episode.
#
# 2.) If the agent was closer to the set target destination, the function gives the agent a large reward. This incentives the agent to get closer to the target destination, and once it does, it receives a large value so that it can continue to learn to move in that direction.
#
# 3.)

# %% [markdown]
# **Question 2**: Discuss your agent briefly, using the following questions as a guide:
#
# - What learning algorithm(s) did you try? What worked best for you?
# - What was your final choice of hyperparameters (such as $\alpha$, $\gamma$, $\epsilon$, etc.)?
# - What neural network architecture did you use (if any)? Specify layers, sizes, activation functions, etc.
#
# **Answer**:
#
# I used a deep deterministric policy gradient algorithm because the agent operates in a continuous action and state spaces. Final choice of hyperparameters for alpha, gamma, and episilon were 0.99, 0.99, 0.01.
#
# -I used a three layer neural network for the actor and critic part of the implementation of the DDPG algorithm; each had 32, 64, and 32 nodes in each respective layer.

# %% [markdown]
# **Question 3**: Using the episode rewards plot, discuss how the agent learned over time.
#
# - Was it an easy task to learn or hard?
# - Was there a gradual learning curve, or an aha moment?
# - How good was the final performance of the agent? (e.g. mean rewards over the last 10 episodes)
#
# **Answer**:
#
# The task of hovering using the reward function I designed is complex: the agent, even after 1,000 episodes, still doesn't achieve positive reward to achieve the goal. I used a deep deterministic policy gradient given that this reinforcement learning problem involved continuous state and action spaces.
#
# -There seems to be an aha moment; throughout the learning process, the agent is losing much of the reward. At around episode 500, the agent begins to lose less reward, indicating that it is near the end goal.
#
# -I used two neural networks, one for the actor and one for the critic. Each had three layers with 32, 64, and 32 nodes, respectively.
#
# -The final performance was not great.

# %% [markdown]
# **Question 4**: Briefly summarize your experience working on this project. You can use the following prompts for ideas.
#
# - What was the hardest part of the project? (e.g. getting started, plotting, specifying the task, etc.)
# - Did you find anything interesting in how the quadcopter or your agent behaved?
#
# **Answer**:
#
# Most of the code is provided in the project description so it makes me think that this project would be more helpful if we had designated mentors to help us work through key concepts that we need to learn. I found it incredibly interesting to see the DDPG algorithm applied to such a complex agent, but I felt like I didn't really understand it especially because no one answered any of my questions. The difference between Udacity and a top-tier university robotics program, and least in this case, is the ability to ask the hard questions and have someone more experienced walk us through the concepts so that we can implement the program.

# %%
np.sum(np.absolute(np.array([-1, 2, -3]) - np.array([0, 0 ,10])))
# Out:
# 16

# %%
mag = np.sum((np.array([0, 0, 10.]) - np.array([0, 0 ,10.]))**2)

# %%
vec = np.array([-1, 2, -3]) - np.array([0, 0 ,10])

# %%
np.sum(vec/mag)
# Out:
# /Users/adrianlievano/anaconda3/envs/quadcop/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
# nan
