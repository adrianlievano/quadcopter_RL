# %% [markdown]
# # Project: Train a Quadcopter How to Fly
#
# Design an agent to fly a quadcopter, and then train it using a reinforcement learning algorithm of your choice!
#
# Try to apply the techniques you have learnt, but also feel free to come up with innovative ideas and test them.

# %% [markdown]
# ## Instructions
#
# Take a look at the files in the directory to better understand the structure of the project.
#
# - `task.py`: Define your task (environment) in this file.
# - `agents/`: Folder containing reinforcement learning agents.
#     - `policy_search.py`: A sample agent has been provided here.
#     - `agent.py`: Develop your agent here.
# - `physics_sim.py`: This file contains the simulator for the quadcopter.  **DO NOT MODIFY THIS FILE**.
#
# For this project, you will define your own task in `task.py`.  Although we have provided a example task to get you started, you are encouraged to change it.  Later in this notebook, you will learn more about how to amend this file.
#
# You will also design a reinforcement learning agent in `agent.py` to complete your chosen task.
#
# You are welcome to create any additional files to help you to organize your code.  For instance, you may find it useful to define a `model.py` file defining any needed neural network architectures.
#
# ## Controlling the Quadcopter
#
# We provide a sample agent in the code cell below to show you how to use the sim to control the quadcopter.  This agent is even simpler than the sample agent that you'll examine (in `agents/policy_search.py`) later in this notebook!
#
# The agent controls the quadcopter by setting the revolutions per second on each of its four rotors.  The provided agent in the `Basic_Agent` class below always selects a random action for each of the four rotors.  These four speeds are returned by the `act` method as a list of four floating-point numbers.
#
# For this project, the agent that you will implement in `agents/agent.py` will have a far more intelligent method for selecting actions!

# %%
import random

class Basic_Agent():
    def __init__(self, task):
        self.task = task
    
    def act(self):
        new_thrust = random.gauss(450., 25.)
        return [new_thrust + random.gauss(0., 1.) for x in range(4)]

# %% [markdown]
# Run the code cell below to have the agent select actions to control the quadcopter.
#
# Feel free to change the provided values of `runtime`, `init_pose`, `init_velocities`, and `init_angle_velocities` below to change the starting conditions of the quadcopter.
#
# The `labels` list below annotates statistics that are saved while running the simulation.  All of this information is saved in a text file `data.txt` and stored in the dictionary `results`.

# %%
#%load_ext autoreload
# %reload_ext autoreload

#%autoreload 2

import csv
import numpy as np
from task import Task

# Modify the values below to give the quadcopter a different starting position.
runtime = 5.                                     # time limit of the episode
init_pose = np.array([0., 0., 10., 0., 0., 0.])  # initial pose
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
file_output = 'data.txt'                         # file name for saved results

# Setup
task = Task(init_pose, init_velocities, init_angle_velocities, runtime)
agent = Basic_Agent(task)
done = False
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

# Run the simulation, and save the results.
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    while True:
        rotor_speeds = agent.act()
        _, _, done = task.step(rotor_speeds)
        to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_write[ii])
        writer.writerow(to_write)
        if done:
            break

# %% [markdown]
# Run the code cell below to visualize how the position of the quadcopter evolved during the simulation.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(results['time'], results['x'], label='x')
plt.plot(results['time'], results['y'], label='y')
plt.plot(results['time'], results['z'], label='z')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# The next code cell visualizes the velocity of the quadcopter.

# %%
plt.plot(results['time'], results['x_velocity'], label='x_hat')
plt.plot(results['time'], results['y_velocity'], label='y_hat')
plt.plot(results['time'], results['z_velocity'], label='z_hat')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Next, you can plot the Euler angles (the rotation of the quadcopter over the $x$-, $y$-, and $z$-axes),

# %%
plt.plot(results['time'], results['phi'], label='phi')
plt.plot(results['time'], results['theta'], label='theta')
plt.plot(results['time'], results['psi'], label='psi')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# before plotting the velocities (in radians per second) corresponding to each of the Euler angles.

# %%
plt.plot(results['time'], results['phi_velocity'], label='phi_velocity')
plt.plot(results['time'], results['theta_velocity'], label='theta_velocity')
plt.plot(results['time'], results['psi_velocity'], label='psi_velocity')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Finally, you can use the code cell below to print the agent's choice of actions.

# %%
plt.plot(results['time'], results['rotor_speed1'], label='Rotor 1 revolutions / second')
plt.plot(results['time'], results['rotor_speed2'], label='Rotor 2 revolutions / second')
plt.plot(results['time'], results['rotor_speed3'], label='Rotor 3 revolutions / second')
plt.plot(results['time'], results['rotor_speed4'], label='Rotor 4 revolutions / second')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# When specifying a task, you will derive the environment state from the simulator.  Run the code cell below to print the values of the following variables at the end of the simulation:
# - `task.sim.pose` (the position of the quadcopter in ($x,y,z$) dimensions and the Euler angles),
# - `task.sim.v` (the velocity of the quadcopter in ($x,y,z$) dimensions), and
# - `task.sim.angular_v` (radians/second for each of the three Euler angles).

# %%
# the pose, velocity, and angular velocity of the quadcopter at the end of the episode
print(task.sim.pose)
print(task.sim.v)
print(task.sim.angular_v)

a=np.concatenate((task.sim.pose, task.sim.v, task.sim.angular_v),axis=0)
print(a)
# Out:
# [-4.86776096  3.4838123  31.89665989  6.27456919  0.27885158  0.        ]
# [-4.58488806  1.6513127   5.92244184]
# [-0.03322715  0.08690351  0.        ]
# [-4.86776096  3.4838123  31.89665989  6.27456919  0.27885158  0.
#  -4.58488806  1.6513127   5.92244184 -0.03322715  0.08690351  0.        ]

# %% [markdown]
# In the sample task in `task.py`, we use the 6-dimensional pose of the quadcopter to construct the state of the environment at each timestep.  However, when amending the task for your purposes, you are welcome to expand the size of the state vector by including the velocity information.  You can use any combination of the pose, velocity, and angular velocity - feel free to tinker here, and construct the state to suit your task.
#
# ## The Task
#
# A sample task has been provided for you in `task.py`.  Open this file in a new window now.
#
# The `__init__()` method is used to initialize several variables that are needed to specify the task.
# - The simulator is initialized as an instance of the `PhysicsSim` class (from `physics_sim.py`).
# - Inspired by the methodology in the original DDPG paper, we make use of action repeats.  For each timestep of the agent, we step the simulation `action_repeats` timesteps.  If you are not familiar with action repeats, please read the **Results** section in [the DDPG paper](https://arxiv.org/abs/1509.02971).
# - We set the number of elements in the state vector.  For the sample task, we only work with the 6-dimensional pose information.  To set the size of the state (`state_size`), we must take action repeats into account.
# - The environment will always have a 4-dimensional action space, with one entry for each rotor (`action_size=4`). You can set the minimum (`action_low`) and maximum (`action_high`) values of each entry here.
# - The sample task in this provided file is for the agent to reach a target position.  We specify that target position as a variable.
#
# The `reset()` method resets the simulator.  The agent should call this method every time the episode ends.  You can see an example of this in the code cell below.
#
# The `step()` method is perhaps the most important.  It accepts the agent's choice of action `rotor_speeds`, which is used to prepare the next state to pass on to the agent.  Then, the reward is computed from `get_reward()`.  The episode is considered done if the time limit has been exceeded, or the quadcopter has travelled outside of the bounds of the simulation.
#
# In the next section, you will learn how to test the performance of an agent on this task.

# %% [markdown]
# ## The Agent
#
# The sample agent given in `agents/policy_search.py` uses a very simplistic linear policy to directly compute the action vector as a dot product of the state vector and a matrix of weights. Then, it randomly perturbs the parameters by adding some Gaussian noise, to produce a different policy. Based on the average reward obtained in each episode (`score`), it keeps track of the best set of parameters found so far, how the score is changing, and accordingly tweaks a scaling factor to widen or tighten the noise.
#
# Run the code cell below to see how the agent performs on the sample task.

# %%
import sys
import pandas as pd
from agents.policy_search import PolicySearch_Agent
from task import Task
import numpy as np

num_episodes = 1000
target_pos = np.array([0., 0., 10.])
task = Task(target_pos=target_pos)
agent = PolicySearch_Agent(task) 

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(reward, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                i_episode, agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
            break
        
    sys.stdout.flush()
# Out:
# Episode = 1000, score = 258.859 (best = 274.923), noise_scale = 3.25

# %%
reward
# Out:
# -58.2653404374481

# %% [markdown]
# This agent should perform very poorly on this task.  And that's where you come in!

# %% [markdown]
# ## Define the Task, Design the Agent, and Train Your Agent!
#
# Amend `task.py` to specify a task of your choosing.  If you're unsure what kind of task to specify, you may like to teach your quadcopter to takeoff, hover in place, land softly, or reach a target pose.
#
# After specifying your task, use the sample agent in `agents/policy_search.py` as a template to define your own agent in `agents/agent.py`.  You can borrow whatever you need from the sample agent, including ideas on how you might modularize your code (using helper methods like `act()`, `learn()`, `reset_episode()`, etc.).
#
# Note that it is **highly unlikely** that the first agent and task that you specify will learn well.  You will likely have to tweak various hyperparameters and the reward function for your task until you arrive at reasonably good behavior.
#
# As you develop your agent, it's important to keep an eye on how it's performing. Use the code above as inspiration to build in a mechanism to log/save the total rewards obtained in each episode to file.  If the episode rewards are gradually increasing, this is an indication that your agent is learning.

# %%
## TODO: Train your agent here.
import sys
import numpy as np
from agents.agent import DDPGAgent
import pandas as pd
from task import Task

num_episodes = 500
target_pos = np.array([0., 0., 100.])
runtime = 10
task = Task(target_pos=target_pos, runtime = runtime)
agent = DDPGAgent(task) 
score = 0.0
best_score = -100

labels = ['Episode', 'Score', 'Best Score']
results = {x : [] for x in labels}

x_pos = []
y_pos = []
z_pos = []
rewards = []

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    x_pos_temp = []
    y_pos_temp = []
    z_pos_temp = []
    
    while True:
        x_pos_temp.append(task.sim.pose[0])
        y_pos_temp.append(task.sim.pose[1])
        z_pos_temp.append(task.sim.pose[2])
        
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        
        score += reward
        best_score = max(best_score, score)

        agent.step(action, reward, next_state, done)
        state = next_state
        
        if done:
            rewards.append(score)

            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}) position = {} {} {}".format(
                i_episode, score, best_score, 
                  round(task.sim.pose[:3][0],1),
                  round(task.sim.pose[:3][1],1),
                  round(task.sim.pose[:3][2],1), end=""))  # [debug]
            x_pos.append(x_pos_temp)
            y_pos.append(y_pos_temp)
            z_pos.append(z_pos_temp)   
            to_write = [i_episode] + [score] + [best_score]
            for ii in range(len(labels)):
                results[labels[ii]].append(to_write[ii])
            break
    sys.stdout.flush()
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /Users/adrianlievano/anaconda3/envs/quadcop/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Episode =    1, score = -629797.905 (best = -100.000) position = 2.0 5.5 0.0
# Episode =    2, score = -1289477.946 (best = -100.000) position = 2.1 5.9 0.0
# WARNING:tensorflow:From /Users/adrianlievano/anaconda3/envs/quadcop/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Episode =    3, score = -1976554.174 (best = -100.000) position = 2.0 6.3 0.0
# Episode =    4, score = -2600566.364 (best = -100.000) position = -1.5 -0.7 0.0
# Episode =    5, score = -4460953.506 (best = -100.000) position = -3.4 20.5 0.0
# Episode =    6, score = -5114860.311 (best = -100.000) position = 0.0 -0.1 0.0
# Episode =    7, score = -5688026.871 (best = -100.000) position = 0.0 -0.0 0.0
# Episode =    8, score = -6261193.679 (best = -100.000) position = -0.0 -0.0 0.0
# Episode =    9, score = -6834360.495 (best = -100.000) position = -0.0 0.0 0.0
# Episode =   10, score = -7407527.309 (best = -100.000) position = 0.0 0.0 0.0
# Episode =   11, score = -7980694.129 (best = -100.000) position = -0.0 -0.0 0.0
# Episode =   12, score = -8553860.950 (best = -100.000) position = -0.0 -0.0 0.0
# Episode =   13, score = -9127027.764 (best = -100.000) position = -0.0 0.0 0.0
# Episode =   14, score = -9700194.572 (best = -100.000) position = -0.0 0.0 0.0
# Episode =   15, score = -10273361.392 (best = -100.000) position = 0.0 0.0 0.0
# Episode =   16, score = -10846528.199 (best = -100.000) position = 0.0 0.0 0.0
# Episode =   17, score = -11419695.013 (best = -100.000) position = -0.0 0.0 0.0
# Episode =   18, score = -11992861.831 (best = -100.000) position = 0.0 0.0 0.0
# Episode =   19, score = -12566028.650 (best = -100.000) position = 0.0 -0.0 0.0
# Episode =   20, score = -13139195.474 (best = -100.000) position = -0.0 0.0 0.0
# Episode =   21, score = -13712362.290 (best = -100.000) position = 0.0 0.0 0.0
# Episode =   22, score = -14285529.115 (best = -100.000) position = 0.0 0.0 0.0
# Episode =   23, score = -14858695.930 (best = -100.000) position = 0.0 -0.0 0.0
# Episode =   24, score = -15431862.747 (best = -100.000) position = 0.0 0.0 0.0
# Episode =   25, score = -16005029.566 (best = -100.000) position = 0.0 0.0 0.0
# Episode =   26, score = -16578196.377 (best = -100.000) position = 0.0 -0.0 0.0
# Episode =   27, score = -17151363.175 (best = -100.000) position = -0.0 0.0 0.0
# Episode =   28, score = -17724529.994 (best = -100.000) position = -0.0 -0.0 0.0
# Episode =   29, score = -18297696.806 (best = -100.000) position = 0.0 0.0 0.0
# Episode =   30, score = -18870863.618 (best = -100.000) position = 0.0 -0.0 0.0
# Episode =   31, score = -19444030.432 (best = -100.000) position = 0.0 -0.0 0.0
# Episode =   32, score = -20017197.249 (best = -100.000) position = 0.0 -0.0 0.0
# Episode =   33, score = -20590364.063 (best = -100.000) position = 0.0 0.0 0.0
# Episode =   34, score = -21163530.878 (best = -100.000) position = -0.0 -0.0 0.0
# Episode =   35, score = -21736697.682 (best = -100.000) position = -0.0 0.0 0.0
# Episode =   36, score = -22309864.502 (best = -100.000) position = 0.0 -0.0 0.0
# Episode =   37, score = -22883031.324 (best = -100.000) position = -0.0 -0.0 0.0
# Episode =   38, score = -23540545.681 (best = -100.000) position = -0.0 0.1 0.0
# Episode =   39, score = -24591104.151 (best = -100.000) position = -0.5 -1.1 0.0
# Episode =   40, score = -26225152.225 (best = -100.000) position = -6.9 7.6 0.0
# Episode =   41, score = -26977161.371 (best = -100.000) position = 0.6 1.9 0.0
# Episode =   42, score = -27729276.590 (best = -100.000) position = -0.4 2.0 0.0
# Episode =   43, score = -28481306.179 (best = -100.000) position = 0.1 2.0 0.0
# Episode =   44, score = -29233384.885 (best = -100.000) position = 1.3 2.0 0.0
# Episode =   45, score = -29985377.543 (best = -100.000) position = 1.1 1.9 0.0
# Episode =   46, score = -30737451.161 (best = -100.000) position = 0.3 2.0 0.0
# Episode =   47, score = -31459861.971 (best = -100.000) position = -0.2 2.0 0.0
# Episode =   48, score = -32211845.236 (best = -100.000) position = 1.5 1.9 0.0
# Episode =   49, score = -32963953.591 (best = -100.000) position = -0.5 2.0 0.0
# Episode =   50, score = -33715898.646 (best = -100.000) position = 0.8 1.9 0.0
# Episode =   51, score = -34467939.385 (best = -100.000) position = -0.1 2.0 0.0
# Episode =   52, score = -35220356.128 (best = -100.000) position = 2.8 2.1 0.0
# Episode =   53, score = -35972276.714 (best = -100.000) position = 1.3 2.0 0.0
# Episode =   54, score = -36724190.825 (best = -100.000) position = 1.0 1.9 0.0
# Episode =   55, score = -37476314.283 (best = -100.000) position = -0.4 2.0 0.0
# Episode =   56, score = -38228186.558 (best = -100.000) position = -1.3 1.9 0.0
# Episode =   57, score = -38980083.056 (best = -100.000) position = -3.5 1.9 0.0
# Episode =   58, score = -39732182.997 (best = -100.000) position = 1.3 2.0 0.0
# Episode =   59, score = -40484413.486 (best = -100.000) position = -2.1 2.0 0.0
# Episode =   60, score = -41236509.972 (best = -100.000) position = 1.3 2.0 0.0
# Episode =   61, score = -41988342.421 (best = -100.000) position = 0.0 1.9 0.0
# Episode =   62, score = -42740278.100 (best = -100.000) position = 0.7 1.9 0.0
# Episode =   63, score = -43492420.647 (best = -100.000) position = 0.1 2.0 0.0
# Episode =   64, score = -44244379.649 (best = -100.000) position = 1.3 1.9 0.0
# Episode =   65, score = -44996331.874 (best = -100.000) position = 1.2 2.0 0.0
# Episode =   66, score = -45748345.032 (best = -100.000) position = -0.8 2.0 0.0
# Episode =   67, score = -46500409.958 (best = -100.000) position = 0.8 2.0 0.0
# Episode =   68, score = -47252402.982 (best = -100.000) position = 1.6 2.0 0.0
# Episode =   69, score = -48004317.382 (best = -100.000) position = -4.0 2.0 0.0
# Episode =   70, score = -48756367.662 (best = -100.000) position = 1.3 2.0 0.0
# Episode =   71, score = -49508391.786 (best = -100.000) position = -1.2 2.0 0.0
# Episode =   72, score = -50260144.242 (best = -100.000) position = -0.7 1.9 0.0
# Episode =   73, score = -51011889.050 (best = -100.000) position = 2.7 1.9 0.0
# Episode =   74, score = -51763877.240 (best = -100.000) position = 0.3 2.0 0.0
# Episode =   75, score = -52515813.735 (best = -100.000) position = -0.9 2.0 0.0
# Episode =   76, score = -53267760.067 (best = -100.000) position = -0.9 1.9 0.0
# Episode =   77, score = -54019902.170 (best = -100.000) position = -0.9 2.0 0.0
# Episode =   78, score = -54771680.630 (best = -100.000) position = 0.3 1.9 0.0
# Episode =   79, score = -55523853.786 (best = -100.000) position = -2.3 2.0 0.0
# Episode =   80, score = -56275764.466 (best = -100.000) position = -0.9 1.9 0.0
# Episode =   81, score = -57027656.231 (best = -100.000) position = -2.5 1.9 0.0
# Episode =   82, score = -57779747.123 (best = -100.000) position = -2.4 2.0 0.0
# Episode =   83, score = -58531873.737 (best = -100.000) position = -1.7 2.0 0.0
# Episode =   84, score = -59283916.781 (best = -100.000) position = 1.5 2.0 0.0
# Episode =   85, score = -60035960.314 (best = -100.000) position = -1.6 2.0 0.0
# Episode =   86, score = -60787871.158 (best = -100.000) position = 1.2 2.0 0.0
# Episode =   87, score = -61539972.280 (best = -100.000) position = -4.1 2.0 0.0
# Episode =   88, score = -62292024.243 (best = -100.000) position = -1.9 2.0 0.0
# Episode =   89, score = -63044100.831 (best = -100.000) position = 0.1 2.0 0.0
# Episode =   90, score = -63795929.105 (best = -100.000) position = 1.0 1.9 0.0
# Episode =   91, score = -64547983.572 (best = -100.000) position = 0.9 2.0 0.0
# Episode =   92, score = -65300070.114 (best = -100.000) position = 1.1 2.0 0.0
# Episode =   93, score = -66052058.831 (best = -100.000) position = -0.3 2.0 0.0
# Episode =   94, score = -66803860.634 (best = -100.000) position = 2.3 1.9 0.0
# Episode =   95, score = -67555854.048 (best = -100.000) position = 0.2 2.0 0.0
# Episode =   96, score = -68307834.676 (best = -100.000) position = 1.0 2.0 0.0
# Episode =   97, score = -69059929.570 (best = -100.000) position = -2.0 2.0 0.0
# Episode =   98, score = -69811631.261 (best = -100.000) position = -3.8 1.9 0.0
# Episode =   99, score = -70563525.468 (best = -100.000) position = -0.7 1.9 0.0
# Episode =  100, score = -71315471.321 (best = -100.000) position = 0.2 2.0 0.0
# Episode =  101, score = -72067269.272 (best = -100.000) position = 1.2 1.9 0.0
# Episode =  102, score = -72819173.387 (best = -100.000) position = -1.8 1.9 0.0
# Episode =  103, score = -73571065.785 (best = -100.000) position = 1.0 1.9 0.0
# Episode =  104, score = -74323163.863 (best = -100.000) position = 2.1 2.0 0.0
# Episode =  105, score = -75074967.492 (best = -100.000) position = -0.9 1.9 0.0
# Episode =  106, score = -75827032.303 (best = -100.000) position = -0.9 2.0 0.0
# Episode =  107, score = -76579049.648 (best = -100.000) position = 1.6 2.0 0.0
# Episode =  108, score = -77331077.942 (best = -100.000) position = 0.5 2.0 0.0
# Episode =  109, score = -78083074.407 (best = -100.000) position = -2.9 2.0 0.0
# Episode =  110, score = -78835105.699 (best = -100.000) position = -1.8 2.0 0.0
# Episode =  111, score = -79557459.203 (best = -100.000) position = 0.3 2.0 0.0
# Episode =  112, score = -80309653.690 (best = -100.000) position = 0.2 2.0 0.0
# Episode =  113, score = -81061620.051 (best = -100.000) position = -2.4 2.0 0.0
# Episode =  114, score = -81813870.748 (best = -100.000) position = 0.4 2.0 0.0
# Episode =  115, score = -82565769.849 (best = -100.000) position = -2.9 2.0 0.0
# Episode =  116, score = -83317794.575 (best = -100.000) position = 2.0 2.0 0.0
# Episode =  117, score = -84069796.315 (best = -100.000) position = 0.9 2.0 0.0
# Episode =  118, score = -84821821.740 (best = -100.000) position = -1.3 2.0 0.0
# Episode =  119, score = -85573999.865 (best = -100.000) position = 0.6 2.0 0.0
# Episode =  120, score = -86326039.142 (best = -100.000) position = -2.0 2.0 0.0
# Episode =  121, score = -87078007.752 (best = -100.000) position = -0.8 2.0 0.0
# Episode =  122, score = -87830162.588 (best = -100.000) position = 1.7 2.0 0.0
# Episode =  123, score = -88582074.977 (best = -100.000) position = 0.3 1.9 0.0
# Episode =  124, score = -89333973.269 (best = -100.000) position = -2.0 1.9 0.0
# Episode =  125, score = -90085843.890 (best = -100.000) position = 0.5 1.9 0.0
# Episode =  126, score = -90837662.329 (best = -100.000) position = 2.1 1.9 0.0
# Episode =  127, score = -91589608.887 (best = -100.000) position = -0.2 2.0 0.0
# Episode =  128, score = -92341695.427 (best = -100.000) position = -0.1 2.0 0.0
# Episode =  129, score = -93093531.751 (best = -100.000) position = 1.8 1.9 0.0
# Episode =  130, score = -93845471.958 (best = -100.000) position = 1.0 1.9 0.0
# Episode =  131, score = -94597439.740 (best = -100.000) position = 1.2 1.9 0.0
# Episode =  132, score = -95349452.820 (best = -100.000) position = 2.5 2.0 0.0
# Episode =  133, score = -96101486.175 (best = -100.000) position = -1.5 2.0 0.0
# Episode =  134, score = -96853425.321 (best = -100.000) position = 0.3 1.9 0.0
# Episode =  135, score = -97605457.678 (best = -100.000) position = -2.9 2.0 0.0
# Episode =  136, score = -98357514.362 (best = -100.000) position = 3.7 2.0 0.0
# Episode =  137, score = -99109565.236 (best = -100.000) position = 1.7 2.0 0.0
# Episode =  138, score = -99861581.527 (best = -100.000) position = -2.1 2.0 0.0
# Episode =  139, score = -100613611.393 (best = -100.000) position = 1.2 2.0 0.0
# Episode =  140, score = -101365791.991 (best = -100.000) position = -0.8 2.0 0.0
# Episode =  141, score = -102117609.465 (best = -100.000) position = -1.6 1.9 0.0
# Episode =  142, score = -102869670.480 (best = -100.000) position = 1.2 2.0 0.0
# Episode =  143, score = -103621759.086 (best = -100.000) position = -0.8 2.0 0.0
# Episode =  144, score = -104373791.459 (best = -100.000) position = 0.6 2.0 0.0
# Episode =  145, score = -105125858.503 (best = -100.000) position = 2.4 2.0 0.0
# Episode =  146, score = -105877709.194 (best = -100.000) position = -1.4 1.9 0.0
# Episode =  147, score = -106629430.264 (best = -100.000) position = -2.5 1.9 0.0
# Episode =  148, score = -107381449.967 (best = -100.000) position = 2.8 2.0 0.0
# Episode =  149, score = -108133560.959 (best = -100.000) position = 0.9 2.0 0.0
# Episode =  150, score = -108885640.216 (best = -100.000) position = -6.2 2.0 0.0
# Episode =  151, score = -109637801.670 (best = -100.000) position = 1.0 2.0 0.0
# Episode =  152, score = -110389852.999 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  153, score = -111141726.538 (best = -100.000) position = 0.8 1.9 0.0
# Episode =  154, score = -111893888.049 (best = -100.000) position = -2.1 2.0 0.0
# Episode =  155, score = -112645858.162 (best = -100.000) position = -0.4 1.9 0.0
# Episode =  156, score = -113397774.889 (best = -100.000) position = -0.7 1.9 0.0
# Episode =  157, score = -114149592.978 (best = -100.000) position = -0.1 1.9 0.0
# Episode =  158, score = -114901410.225 (best = -100.000) position = -0.4 1.9 0.0
# Episode =  159, score = -115653536.425 (best = -100.000) position = 1.3 2.0 0.0
# Episode =  160, score = -116405536.348 (best = -100.000) position = -0.9 2.0 0.0
# Episode =  161, score = -117157694.792 (best = -100.000) position = 0.9 2.0 0.0
# Episode =  162, score = -117909693.251 (best = -100.000) position = 1.0 2.0 0.0
# Episode =  163, score = -118661695.098 (best = -100.000) position = 0.3 2.0 0.0
# Episode =  164, score = -119413688.136 (best = -100.000) position = -1.7 2.0 0.0
# Episode =  165, score = -120165644.522 (best = -100.000) position = 1.3 2.0 0.0
# Episode =  166, score = -120917639.097 (best = -100.000) position = -0.9 1.9 0.0
# Episode =  167, score = -121669562.949 (best = -100.000) position = 0.3 2.0 0.0
# Episode =  168, score = -122421838.830 (best = -100.000) position = 0.8 2.0 0.0
# Episode =  169, score = -123173687.586 (best = -100.000) position = 0.1 1.9 0.0
# Episode =  170, score = -123925749.608 (best = -100.000) position = 1.9 2.0 0.0
# Episode =  171, score = -124677750.069 (best = -100.000) position = -2.0 1.9 0.0
# Episode =  172, score = -125429690.921 (best = -100.000) position = 1.1 2.0 0.0
# Episode =  173, score = -126181762.261 (best = -100.000) position = 0.9 2.0 0.0
# Episode =  174, score = -126933628.283 (best = -100.000) position = 0.2 1.9 0.0
# Episode =  175, score = -127685592.938 (best = -100.000) position = -0.9 2.0 0.0
# Episode =  176, score = -128437592.177 (best = -100.000) position = 0.5 2.0 0.0
# Episode =  177, score = -129189638.346 (best = -100.000) position = 0.3 2.0 0.0
# Episode =  178, score = -129941921.247 (best = -100.000) position = -0.2 2.0 0.0
# Episode =  179, score = -130694182.150 (best = -100.000) position = -0.5 2.0 0.0
# Episode =  180, score = -131446230.777 (best = -100.000) position = 1.7 2.0 0.0
# Episode =  181, score = -132198215.382 (best = -100.000) position = -1.5 2.0 0.0
# Episode =  182, score = -132950135.392 (best = -100.000) position = 1.3 1.9 0.0
# Episode =  183, score = -133702140.030 (best = -100.000) position = 1.4 2.0 0.0
# Episode =  184, score = -134454165.302 (best = -100.000) position = -0.4 2.0 0.0
# Episode =  185, score = -135206177.735 (best = -100.000) position = -2.1 2.0 0.0
# Episode =  186, score = -135958041.682 (best = -100.000) position = -0.9 1.9 0.0
# Episode =  187, score = -136709820.529 (best = -100.000) position = 1.8 1.9 0.0
# Episode =  188, score = -137461839.360 (best = -100.000) position = -0.5 2.0 0.0
# Episode =  189, score = -138214051.027 (best = -100.000) position = 0.5 2.0 0.0
# Episode =  190, score = -138965839.907 (best = -100.000) position = 1.8 1.9 0.0
# Episode =  191, score = -139718002.618 (best = -100.000) position = 0.3 2.0 0.0
# Episode =  192, score = -140470022.508 (best = -100.000) position = -1.1 2.0 0.0
# Episode =  193, score = -141222106.621 (best = -100.000) position = -1.7 2.0 0.0
# Episode =  194, score = -141974134.959 (best = -100.000) position = -0.5 2.0 0.0
# Episode =  195, score = -142726180.615 (best = -100.000) position = 1.7 2.0 0.0
# Episode =  196, score = -143477924.212 (best = -100.000) position = -1.0 1.9 0.0
# Episode =  197, score = -144230006.218 (best = -100.000) position = -1.6 2.0 0.0
# Episode =  198, score = -144981938.117 (best = -100.000) position = -0.8 1.9 0.0
# Episode =  199, score = -145733750.345 (best = -100.000) position = -1.1 1.9 0.0
# Episode =  200, score = -146485720.805 (best = -100.000) position = 0.5 2.0 0.0
# Episode =  201, score = -147237534.552 (best = -100.000) position = -1.8 1.9 0.0
# Episode =  202, score = -147989388.951 (best = -100.000) position = -1.2 1.9 0.0
# Episode =  203, score = -148741494.779 (best = -100.000) position = 1.0 2.0 0.0
# Episode =  204, score = -149493519.721 (best = -100.000) position = 1.0 2.0 0.0
# Episode =  205, score = -150245462.128 (best = -100.000) position = -2.9 1.9 0.0
# Episode =  206, score = -150997586.001 (best = -100.000) position = -1.8 2.0 0.0
# Episode =  207, score = -151749560.543 (best = -100.000) position = 3.1 1.9 0.0
# Episode =  208, score = -152501755.434 (best = -100.000) position = 1.0 2.0 0.0
# Episode =  209, score = -153253581.698 (best = -100.000) position = 0.1 2.0 0.0
# Episode =  210, score = -154005505.324 (best = -100.000) position = -0.5 1.9 0.0
# Episode =  211, score = -154757745.107 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  212, score = -155509594.520 (best = -100.000) position = -1.2 1.9 0.0
# Episode =  213, score = -156261851.620 (best = -100.000) position = -0.2 2.0 0.0
# Episode =  214, score = -157014056.324 (best = -100.000) position = -0.6 2.0 0.0
# Episode =  215, score = -157766120.822 (best = -100.000) position = -2.7 2.0 0.0
# Episode =  216, score = -158518047.795 (best = -100.000) position = -0.7 2.0 0.0
# Episode =  217, score = -159269873.343 (best = -100.000) position = 0.3 1.9 0.0
# Episode =  218, score = -160021745.322 (best = -100.000) position = -1.9 2.0 0.0
# Episode =  219, score = -160774078.491 (best = -100.000) position = -1.6 2.0 0.0
# Episode =  220, score = -161526364.585 (best = -100.000) position = -1.9 2.0 0.0
# Episode =  221, score = -162248692.438 (best = -100.000) position = -0.2 2.0 0.0
# Episode =  222, score = -163000719.415 (best = -100.000) position = -0.9 1.9 0.0
# Episode =  223, score = -163752871.440 (best = -100.000) position = -1.7 2.0 0.0
# Episode =  224, score = -164504994.578 (best = -100.000) position = 0.8 2.0 0.0
# Episode =  225, score = -165256913.257 (best = -100.000) position = -1.2 2.0 0.0
# Episode =  226, score = -166008696.351 (best = -100.000) position = 3.3 1.9 0.0
# Episode =  227, score = -166760460.091 (best = -100.000) position = -1.5 1.9 0.0
# Episode =  228, score = -167512326.515 (best = -100.000) position = 2.3 1.9 0.0
# Episode =  229, score = -168264422.052 (best = -100.000) position = 2.2 2.0 0.0
# Episode =  230, score = -169016612.038 (best = -100.000) position = -1.0 2.0 0.0
# Episode =  231, score = -169768611.982 (best = -100.000) position = 1.3 2.0 0.0
# Episode =  232, score = -170520594.016 (best = -100.000) position = -1.9 2.0 0.0
# Episode =  233, score = -171272676.413 (best = -100.000) position = 1.5 2.0 0.0
# Episode =  234, score = -172024530.771 (best = -100.000) position = -2.8 1.9 0.0
# Episode =  235, score = -172776527.190 (best = -100.000) position = 1.5 2.0 0.0
# Episode =  236, score = -173421244.476 (best = -100.000) position = 1.8 6.5 0.0
# Episode =  237, score = -177353869.465 (best = -100.000) position = -14.8 -103.9 0.0
# Episode =  238, score = -183696922.268 (best = -100.000) position = -16.9 -147.4 0.0
# Episode =  239, score = -188161120.550 (best = -100.000) position = -15.4 -115.6 0.0
# Episode =  240, score = -191591610.442 (best = -100.000) position = -14.0 -92.2 0.0
# Episode =  241, score = -194332633.407 (best = -100.000) position = -12.5 -73.6 0.0
# Episode =  242, score = -197494654.133 (best = -100.000) position = -13.4 -84.8 0.0
# Episode =  243, score = -198120109.311 (best = -100.000) position = 0.2 -0.1 0.0
# Episode =  244, score = -198850177.572 (best = -100.000) position = -0.6 2.3 0.0
# Episode =  245, score = -199690872.742 (best = -100.000) position = 6.7 0.3 0.0
# Episode =  246, score = -200365307.786 (best = -100.000) position = -4.3 1.9 0.0
# Episode =  247, score = -201039947.058 (best = -100.000) position = -5.8 -0.9 0.0
# Episode =  248, score = -201767559.145 (best = -100.000) position = -7.3 -0.5 0.0
# Episode =  249, score = -202515195.162 (best = -100.000) position = -6.6 -0.3 0.0
# Episode =  250, score = -203211938.319 (best = -100.000) position = -2.4 -1.6 0.0
# Episode =  251, score = -204034281.213 (best = -100.000) position = -8.1 -0.3 0.0
# Episode =  252, score = -204877365.889 (best = -100.000) position = -18.0 0.3 0.0
# Episode =  253, score = -205416735.492 (best = -100.000) position = -4.8 0.1 0.0
# Episode =  254, score = -206185211.637 (best = -100.000) position = 2.6 0.1 0.0
# Episode =  255, score = -206944962.199 (best = -100.000) position = 1.6 0.0 0.0
# Episode =  256, score = -207711579.631 (best = -100.000) position = 5.9 -0.3 0.0
# Episode =  257, score = -208426059.927 (best = -100.000) position = 1.2 -0.3 0.0
# Episode =  258, score = -209251332.728 (best = -100.000) position = 10.9 -0.0 0.0
# Episode =  259, score = -210035389.344 (best = -100.000) position = 4.3 -0.1 0.0
# Episode =  260, score = -210799881.616 (best = -100.000) position = 1.6 0.0 0.0
# Episode =  261, score = -211689182.357 (best = -100.000) position = -16.2 0.1 0.0
# Episode =  262, score = -212304048.841 (best = -100.000) position = 0.6 -0.0 0.0
# Episode =  263, score = -213223379.669 (best = -100.000) position = 2.3 0.0 0.0
# Episode =  264, score = -214187097.090 (best = -100.000) position = -11.5 -0.2 0.0
# Episode =  265, score = -214830580.025 (best = -100.000) position = -8.5 -0.0 0.0
# Episode =  266, score = -215552276.195 (best = -100.000) position = -1.9 -0.3 0.0
# Episode =  267, score = -216302625.312 (best = -100.000) position = -7.6 -0.0 0.0
# Episode =  268, score = -217198597.587 (best = -100.000) position = -11.9 0.1 0.0
# Episode =  269, score = -218602226.815 (best = -100.000) position = 96.4 -150.0 300.0
# Episode =  270, score = -220414034.841 (best = -100.000) position = -23.2 35.6 300.0
# Episode =  271, score = -223112231.391 (best = -100.000) position = -19.3 -150.0 118.1
# Episode =  272, score = -224201711.401 (best = -100.000) position = -8.0 103.0 300.0
# Episode =  273, score = -228161046.240 (best = -100.000) position = -81.3 -142.4 0.0
# Episode =  274, score = -228980928.688 (best = -100.000) position = -18.0 -0.0 0.0
# Episode =  275, score = -229650303.334 (best = -100.000) position = -0.8 0.1 0.0
# Episode =  276, score = -230214591.040 (best = -100.000) position = -6.7 -0.1 0.0
# Episode =  277, score = -230885304.783 (best = -100.000) position = -10.5 0.0 0.0
# Episode =  278, score = -231772611.131 (best = -100.000) position = -6.1 -0.6 0.0
# Episode =  279, score = -232634055.962 (best = -100.000) position = -0.9 0.2 0.0
# Episode =  280, score = -233227118.356 (best = -100.000) position = -5.2 -0.3 0.0
# Episode =  281, score = -233897078.351 (best = -100.000) position = -1.1 0.2 0.0
# Episode =  282, score = -234747576.265 (best = -100.000) position = -6.0 -0.6 0.0
# Episode =  283, score = -235522350.913 (best = -100.000) position = -7.0 0.0 0.0
# Episode =  284, score = -236234206.027 (best = -100.000) position = -9.5 0.1 0.0
# Episode =  285, score = -236942635.996 (best = -100.000) position = -1.2 0.2 0.0
# Episode =  286, score = -237902595.950 (best = -100.000) position = -7.2 -0.8 0.0
# Episode =  287, score = -238918668.369 (best = -100.000) position = -7.3 1.1 0.0
# Episode =  288, score = -239745961.641 (best = -100.000) position = -15.3 -0.2 0.0
# Episode =  289, score = -240631777.189 (best = -100.000) position = -13.9 0.0 0.0
# Episode =  290, score = -241403557.189 (best = -100.000) position = -11.2 -0.1 0.0
# Episode =  291, score = -242355842.691 (best = -100.000) position = -6.7 -1.7 0.0
# Episode =  292, score = -243097697.456 (best = -100.000) position = 3.4 -0.1 0.0
# Episode =  293, score = -243598088.669 (best = -100.000) position = -3.2 0.0 0.0
# Episode =  294, score = -244798111.941 (best = -100.000) position = -2.0 0.5 0.0
# Episode =  295, score = -245756365.832 (best = -100.000) position = -7.4 0.5 0.0
# Episode =  296, score = -246492075.607 (best = -100.000) position = -2.9 0.1 0.0
# Episode =  297, score = -247212173.584 (best = -100.000) position = -10.4 0.1 0.0
# Episode =  298, score = -248567815.729 (best = -100.000) position = 0.1 15.0 168.8
# Episode =  299, score = -250893504.325 (best = -100.000) position = 0.1 118.5 70.1
# Episode =  300, score = -252874112.834 (best = -100.000) position = 17.7 -80.6 0.0
# Episode =  301, score = -253554304.160 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  302, score = -254234616.250 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  303, score = -255469343.179 (best = -100.000) position = -1.4 24.0 0.0
# Episode =  304, score = -258880474.559 (best = -100.000) position = -3.8 -90.2 0.0
# Episode =  305, score = -262944048.168 (best = -100.000) position = -3.3 -109.8 0.0
# Episode =  306, score = -266922093.223 (best = -100.000) position = -3.5 -107.1 0.0
# Episode =  307, score = -273237554.092 (best = -100.000) position = -3.9 -150.0 5.0
# Episode =  308, score = -276067311.058 (best = -100.000) position = -2.9 -79.3 0.0
# Episode =  309, score = -278651726.968 (best = -100.000) position = -2.8 -72.0 0.0
# Episode =  310, score = -281443745.298 (best = -100.000) position = -2.8 -78.2 0.0
# Episode =  311, score = -285325735.956 (best = -100.000) position = -3.3 -105.8 0.0
# Episode =  312, score = -289778200.452 (best = -100.000) position = -3.4 -118.7 0.0
# Episode =  313, score = -292152563.616 (best = -100.000) position = -2.8 -65.8 0.0
# Episode =  314, score = -296522074.390 (best = -100.000) position = -3.4 -116.2 0.0
# Episode =  315, score = -298682091.354 (best = -100.000) position = -2.6 -58.8 0.0
# Episode =  316, score = -302336045.987 (best = -100.000) position = -3.9 -99.7 0.0
# Episode =  317, score = -303016094.899 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  318, score = -303695590.396 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  319, score = -304375906.075 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  320, score = -305055515.989 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  321, score = -305735799.403 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  322, score = -306416235.306 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  323, score = -307096538.782 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  324, score = -307776021.270 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  325, score = -308455614.968 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  326, score = -309135741.817 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  327, score = -309815224.605 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  328, score = -310495611.610 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  329, score = -311175614.841 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  330, score = -311855969.741 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  331, score = -312535960.407 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  332, score = -313216107.241 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  333, score = -313896275.271 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  334, score = -314576495.710 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  335, score = -315256409.916 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  336, score = -315936440.615 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  337, score = -316615824.016 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  338, score = -317295765.035 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  339, score = -317976136.855 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  340, score = -318656398.460 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  341, score = -319336628.200 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  342, score = -320016360.706 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  343, score = -320696807.411 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  344, score = -321376766.563 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  345, score = -322056970.960 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  346, score = -322737167.566 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  347, score = -323417806.707 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  348, score = -324098124.077 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  349, score = -324778345.722 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  350, score = -325458041.734 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  351, score = -326137767.606 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  352, score = -326817751.371 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  353, score = -327497452.666 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  354, score = -328177476.819 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  355, score = -328857347.441 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  356, score = -329536901.532 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  357, score = -330216639.101 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  358, score = -330896634.608 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  359, score = -331576593.483 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  360, score = -332256472.152 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  361, score = -332936609.947 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  362, score = -333616226.910 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  363, score = -334296478.305 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  364, score = -334976277.967 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  365, score = -335656031.938 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  366, score = -336336101.114 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  367, score = -337016484.339 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  368, score = -337696079.301 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  369, score = -338375885.663 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  370, score = -339055982.908 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  371, score = -339736229.752 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  372, score = -340416076.266 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  373, score = -341095774.036 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  374, score = -341775858.441 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  375, score = -342455946.848 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  376, score = -343136594.961 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  377, score = -343816517.055 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  378, score = -344496299.734 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  379, score = -345176282.811 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  380, score = -345855964.330 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  381, score = -346535984.365 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  382, score = -347216280.910 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  383, score = -347895980.454 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  384, score = -348576131.362 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  385, score = -349255949.021 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  386, score = -349935919.478 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  387, score = -350615887.140 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  388, score = -351295959.965 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  389, score = -351975333.277 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  390, score = -352654988.027 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  391, score = -353335006.690 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  392, score = -354014921.881 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  393, score = -354694812.697 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  394, score = -355374726.494 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  395, score = -356054553.492 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  396, score = -356734817.802 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  397, score = -357414914.419 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  398, score = -358095075.085 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  399, score = -358775112.752 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  400, score = -359454823.098 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  401, score = -360134475.752 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  402, score = -360814125.879 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  403, score = -361493932.681 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  404, score = -362173841.648 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  405, score = -362854417.648 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  406, score = -363534141.892 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  407, score = -364213627.781 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  408, score = -364893547.018 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  409, score = -365573080.777 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  410, score = -366252582.968 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  411, score = -366932401.495 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  412, score = -367612054.132 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  413, score = -368291924.923 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  414, score = -368971582.920 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  415, score = -369651393.212 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  416, score = -370331465.626 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  417, score = -371011688.863 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  418, score = -371691488.253 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  419, score = -372371556.346 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  420, score = -373051580.856 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  421, score = -373731289.975 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  422, score = -374412138.626 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  423, score = -375091832.098 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  424, score = -375771479.480 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  425, score = -376451059.514 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  426, score = -377131046.209 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  427, score = -377810672.398 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  428, score = -378490693.371 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  429, score = -379170962.144 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  430, score = -379850973.331 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  431, score = -380530820.481 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  432, score = -381211234.390 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  433, score = -381891257.114 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  434, score = -382570989.073 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  435, score = -383251038.305 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  436, score = -383931185.520 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  437, score = -384610880.152 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  438, score = -385290765.129 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  439, score = -385970759.493 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  440, score = -386650575.452 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  441, score = -387330341.812 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  442, score = -388010484.755 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  443, score = -388690760.641 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  444, score = -389371076.183 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  445, score = -390051260.456 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  446, score = -390731586.703 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  447, score = -391411044.944 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  448, score = -392090923.811 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  449, score = -392770956.090 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  450, score = -393451084.870 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  451, score = -394131014.529 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  452, score = -394811058.552 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  453, score = -395491137.215 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  454, score = -396171335.794 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  455, score = -396851031.395 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  456, score = -397530720.984 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  457, score = -398210545.362 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  458, score = -398890723.164 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  459, score = -399570641.301 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  460, score = -400250824.883 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  461, score = -400930678.567 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  462, score = -401610611.214 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  463, score = -402290258.409 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  464, score = -402970299.546 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  465, score = -403650126.397 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  466, score = -404329639.523 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  467, score = -405009485.506 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  468, score = -405689656.010 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  469, score = -406369838.337 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  470, score = -407050234.114 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  471, score = -407730108.834 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  472, score = -408409951.925 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  473, score = -409090023.124 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  474, score = -409769986.957 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  475, score = -410449895.403 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  476, score = -411130120.670 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  477, score = -411810173.416 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  478, score = -412490277.092 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  479, score = -413170308.485 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  480, score = -413850433.924 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  481, score = -414530300.807 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  482, score = -415211089.490 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  483, score = -415890591.548 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  484, score = -416571008.087 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  485, score = -417250827.149 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  486, score = -417930766.833 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  487, score = -418610889.227 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  488, score = -419291058.969 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  489, score = -419971163.604 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  490, score = -420651525.297 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  491, score = -421331312.937 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  492, score = -422011684.701 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  493, score = -422691762.008 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  494, score = -423371764.937 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  495, score = -424052269.360 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  496, score = -424732209.914 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  497, score = -425411940.618 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  498, score = -426091976.633 (best = -100.000) position = 0.0 2.0 0.0
# Episode =  499, score = -426771896.297 (best = -100.000) position = -0.0 2.0 0.0
# Episode =  500, score = -427451787.031 (best = -100.000) position = 0.0 2.0 0.0

# %%
target_pos
# Out:
# array([  0.,   0., 100.])

# %%
task.sim.pose
# Out:
# array([5.21619948e-05, 1.99684801e+00, 0.00000000e+00, 1.91105798e+00,
#        6.28314913e+00, 0.00000000e+00])

# %%
reward
# Out:
# -29966.882013418624

# %% [markdown]
# ## Plot the Rewards
#
# Once you are satisfied with your performance, plot the episode rewards, either from a single run, or averaged over multiple runs.

# %%
## TODO: Plot the rewards.
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(results['Episode'], results['Score'], label='Reward')
#plt.plot(results['Episode'], rewards, label = 'Reward magnitude over episode')
#plt.plot(results['Episode'], results['Best Score'], label='Best total reward')
plt.xlabel('Episode number')
plt.ylabel('Accumulated Score')
plt.legend()

# %% [markdown]
# ## TEST LEARNED AGENT ##

# %%
#%load_ext autoreload
# %reload_ext autoreload

#%autoreload 2

import csv
import numpy as np
from task import Task

# Modify the values below to give the quadcopter a different starting position.
runtime = 5.                                     # time limit of the episode
init_pose = np.array([0., 0., 10., 0., 0., 0.])  # initial pose
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
file_output = 'data.txt'                         # file name for saved results

# Setup
task = Task(init_pose, init_velocities, init_angle_velocities, runtime)
agent = DDPGAgent(task)
done = False
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

# Run the simulation, and save the results.
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    while True:
        rotor_speeds = agent.act()
        _, _, done = task.step(rotor_speeds)
        to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_write[ii])
        writer.writerow(to_write)
        if done:
            break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-f648e9b39922> in <module>
#      29     writer.writerow(labels)
#      30     while True:
# ---> 31         rotor_speeds = agent.act()
#      32         _, _, done = task.step(rotor_speeds)
#      33         to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
#
# TypeError: act() missing 1 required positional argument: 'state'

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(results['time'], results['x'], label='x')
plt.plot(results['time'], results['y'], label='y')
plt.plot(results['time'], results['z'], label='z')
plt.legend()
_ = plt.ylim()

# %%
plt.plot(results['time'], results['phi'], label='phi')
plt.plot(results['time'], results['theta'], label='theta')
plt.plot(results['time'], results['psi'], label='psi')
plt.legend()
_ = plt.ylim()

# %%
plt.plot(results['time'], results['phi_velocity'], label='phi_velocity')
plt.plot(results['time'], results['theta_velocity'], label='theta_velocity')
plt.plot(results['time'], results['psi_velocity'], label='psi_velocity')
plt.legend()
_ = plt.ylim()

# %%
plt.plot(results['time'], results['rotor_speed1'], label='Rotor 1 revolutions / second')
plt.plot(results['time'], results['rotor_speed2'], label='Rotor 2 revolutions / second')
plt.plot(results['time'], results['rotor_speed3'], label='Rotor 3 revolutions / second')
plt.plot(results['time'], results['rotor_speed4'], label='Rotor 4 revolutions / second')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# ## Reflections
#
# **Question 1**: Describe the task that you specified in `task.py`.  How did you design the reward function?
#
# **Answer**:

# %% [markdown]
# **Question 2**: Discuss your agent briefly, using the following questions as a guide:
#
# - What learning algorithm(s) did you try? What worked best for you?
# - What was your final choice of hyperparameters (such as $\alpha$, $\gamma$, $\epsilon$, etc.)?
# - What neural network architecture did you use (if any)? Specify layers, sizes, activation functions, etc.
#
# **Answer**:
#
# I used a deep deterministric policy gradient algorithm because the agent operates in a continuous action and state spaces. Final choice of hyperparameters for alpha, gamma, and episilon were 0.99, 0.99, 0.01.
#
# -I used a three layer neural network for the actor and critic part of the implementation of the DDPG algorithm; each had 32, 64, and 32 nodes in each respective layer.

# %% [markdown]
# **Question 3**: Using the episode rewards plot, discuss how the agent learned over time.
#
# - Was it an easy task to learn or hard?
# - Was there a gradual learning curve, or an aha moment?
# - How good was the final performance of the agent? (e.g. mean rewards over the last 10 episodes)
#
# **Answer**:
#
# The task of hovering using the reward function I designed is complex: the agent, even after 1,000 episodes, still doesn't achieve positive reward to achieve the goal. I used a deep deterministic policy gradient given that this reinforcement learning problem involved continuous state and action spaces.
#
# -There seems to be an aha moment; throughout the learning process, the agent is losing much of the reward. At around episode 500, the agent begins to lose less reward, indicating that it is near the end goal.
#
# -I used two neural networks, one for the actor and one for the critic. Each had three layers with 32, 64, and 32 nodes, respectively.
#
# -The final performance was not great.

# %% [markdown]
# **Question 4**: Briefly summarize your experience working on this project. You can use the following prompts for ideas.
#
# - What was the hardest part of the project? (e.g. getting started, plotting, specifying the task, etc.)
# - Did you find anything interesting in how the quadcopter or your agent behaved?
#
# **Answer**:
#
# Most of the code is provided in the project description so it makes me think that this project would be more helpful if we had designated mentors to help us work through key concepts that we need to learn. I found it incredibly interesting to see the DDPG algorithm applied to such a complex agent, but I felt like I didn't really understand it especially because no one answered any of my questions. The difference between Udacity and a top-tier university robotics program, and least in this case, is the ability to ask the hard questions and have someone more experienced walk us through the concepts so that we can implement the program.

# %%
np.sum(np.absolute(np.array([-1, 2, -3]) - np.array([0, 0 ,10])))
# Out:
# 16

# %%
mag = np.sum((np.array([0, 0, 10.]) - np.array([0, 0 ,10.]))**2)

# %%
vec = np.array([-1, 2, -3]) - np.array([0, 0 ,10])

# %%
np.sum(vec/mag)
# Out:
# /Users/adrianlievano/anaconda3/envs/quadcop/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
# nan
